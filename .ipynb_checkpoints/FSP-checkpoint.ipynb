# %%
import FSP as fsp
import RandomSearch
import numpy as np
import pandas as pd
import timeit
import os
import matplotlib.pyplot as plt

# %%
Best_known=[1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143]

# %% [markdown]
# # Tests

# %% [markdown]
# ## 1. Branch and Bound

# %%
# jobs = 10, machines : 10, Cmax = 1097, sigma = [ 3 1 2 8 4 7 9 10 6 5 ]
data = np.array([
    [50, 23, 35,  8, 41, 71, 44, 79, 85, 22],
    [37, 75, 94, 76, 17, 28, 99, 36, 14, 96],
    [25, 80, 36, 37,  1, 31, 16, 56, 53, 71],
    [86, 15, 17, 60, 46, 50, 20, 38, 76,  8],
    [51, 22, 34, 14, 11, 53, 40, 35,  9, 15],
    [21, 97, 48, 61, 77, 67, 14,  6, 95,  7],
    [68, 72, 20, 67,  1,  2, 48, 85, 89, 62],
    [29, 81, 91, 25, 60, 76, 44, 76, 28, 95],
    [52,  1, 29, 13,  6, 45, 64, 41, 32, 46],
    [14, 91, 92, 98, 99, 56, 79, 66, 25, 79]
]).T

flowshop = fsp.FlowShop(data)

temps_debut = timeit.default_timer()
sigma, cmax = flowshop.branchBound()
temps_fin = timeit.default_timer() - temps_debut

print("Jobs : ", flowshop.N, " - Machines : ", flowshop.M)
print("Best permutation : ", sigma.astype(int))
print("Cmax : ", int(cmax))
print("Time : ", temps_fin)

# %%
# instance 01:
# jobs = 20, machines : 5
data =np.loadtxt('./Instances_Taillard/20jobs_5machines_1.txt')

flowshop = fsp.FlowShop(data)

temps_debut = timeit.default_timer()
sigma, cmax = flowshop.branchBound()
temps_fin = timeit.default_timer() - temps_debut

print("Jobs : ", flowshop.N, " - Machines : ", flowshop.M)
print("Best permutation : ", sigma.astype(int))
print("Cmax : ", int(cmax))
print("Time : ", temps_fin)

# %%
#instance 2:celle qui a fonctionné
# jobs = 20, machines : 5
data =np.loadtxt('./Instances_Taillard/20jobs_5machines_2.txt')

flowshop = fsp.FlowShop(data)

temps_debut = timeit.default_timer()
sigma, cmax = flowshop.branchBound()
temps_fin = timeit.default_timer() - temps_debut

print("Jobs : ", flowshop.N, " - Machines : ", flowshop.M)
print("Best permutation : ", sigma.astype(int))
print("Cmax : ", int(cmax))
print("Time : ", temps_fin)

# %% [markdown]
# ## 2. Les heuristiques

# %%
cds_cmax = []
neh_cmax = []
palmer_cmax = []
machines=[]
jobs=[]
Instances=[]


neh_temps = []

# %%
#on parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #CDS
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.CDS()
    cds_cmax.append(int(cmax))
    
    #Palmer
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.palmer_heuristic()
    temps_fin = timeit.default_timer() - temps_debut
    palmer_cmax.append(int(cmax))
    
    #NEH
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH()
    temps_fin = timeit.default_timer() - temps_debut
    neh_cmax.append(int(cmax))
    neh_temps.append(temps_fin)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt
# 500jobs_20machines_1.txt
# 500jobs_20machines_2.txt

# %%
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
                   6183,10862,10480,11152,11143,26040,26040],
    "Palmer" : palmer_cmax,
    "CDS" : cds_cmax,
    "NEH" : neh_cmax
})
# Out:
#     jobs  machines  Instance  Best Known  Palmer    CDS    NEH
# 0     20         5         1        1278    1384   1390   1286
# 1     20         5         2        1359    1439   1424   1365
# 2     20        10         1        1582    1790   1757   1680
# 3     20        10         2        1659    1948   1854   1729
# 4     20        20         1        2297    2818   2559   2410
# 5     20        20         2        2099    2331   2285   2150
# 6     50         5         1        2724    2774   2883   2733
# 7     50         5         2        2834    3014   3032   2843
# 8     50        10         1        2991    3453   3382   3135
# 9     50        10         2        2867    3313   3263   3032
# 10    50        20         1        3771    4272   4324   4082
# 11    50        20         2        3668    4303   4216   3921
# 12   100         5         1        5493    5749   5592   5519
# 13   100         5         2        5268    5316   5548   5348
# 14   100        10         1        5770    6161   6239   5846
# 15   100        10         2        5349    5889   5851   5453
# 16   100        20         1        6106    7075   6962   6541
# 17   100        20         2        6183    7058   6970   6523
# 18   200        10         1       10862   11443  11610  10942
# 19   200        10         2       10480   10986  11358  10716
# 20   200        20         1       11152   13042  12536  11594
# 21   200        20         2       11143   12813  12558  11675
# 22   500        20         1       26040   28246  28385  26670
# 23   500        20         2       26040   29439  29091  27232

# %% [markdown]
# ## 2. Paramétrage et variantes

# %% [markdown]
# ### 1. CDS

# %%
cds_cmax = []
cds2_cmax = []
cds3_cmax = []
machines=[]
jobs=[]
Instances=[]

# %%
#on parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #CDS | nbSeq = M-1
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.CDS()
    cds_cmax.append(int(cmax))
    
    #CDS | nbSeq = (M-1)/2
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.CDS(round((flowshop.M-1)/2))
    temps_fin = timeit.default_timer() - temps_debut
    cds2_cmax.append(int(cmax))
    
    #CDS | nbSeq = (M-1)/4
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.CDS(round((flowshop.M-1)/4))
    temps_fin = timeit.default_timer() - temps_debut
    cds3_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt
# 500jobs_20machines_1.txt
# 500jobs_20machines_2.txt

# %%
print("CDS - Variation du paramètre : nbSeq")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
                   6183,10862,10480,11152,11143,26040,26040],
    "nbSeq = M-1" : cds_cmax,
    "nbSeq = (M-1)/2" : cds2_cmax,
    "nbSeq = (M-1)/4" : cds3_cmax
})
# Out:
# CDS - Variation du paramètre : nbSeq
#     jobs  machines  Instance  Best Known  nbSeq = M-1  nbSeq = (M-1)/2  \
# 0     20         5         1        1278         1390             1390
# 1     20         5         2        1359         1424             1432
# 2     20        10         1        1582         1757             1791
# 3     20        10         2        1659         1854             1854
# 4     20        20         1        2297         2559             2559
# 5     20        20         2        2099         2285             2285
# 6     50         5         1        2724         2883             2926
# 7     50         5         2        2834         3032             3032
# 8     50        10         1        2991         3382             3382
# 9     50        10         2        2867         3263             3263
# 10    50        20         1        3771         4324             4324
# 11    50        20         2        3668         4216             4216
# 12   100         5         1        5493         5592             5751
# 13   100         5         2        5268         5548             5548
# 14   100        10         1        5770         6239             6239
# 15   100        10         2        5349         5851             5851
# 16   100        20         1        6106         6962             6962
# 17   100        20         2        6183         6970             6970
# 18   200        10         1       10862        11610            11695
# 19   200        10         2       10480        11358            11358
# 20   200        20         1       11152        12536            12618
# 21   200        20         2       11143        12558            12558
# 22   500        20         1       26040        28385            28385
# 23   500        20         2       26040        29091            29091
#
#     nbSeq = (M-1)/4
# 0              1390
# 1              1432
# 2              1791
# 3              1854
# 4              2559
# 5              2353
# 6              2926
# 7              3032
# 8              3645
# 9              3335
# 10             4324
# 11             4237
# 12             5751
# 13             5665
# 14             6239
# 15             5864
# 16             6962
# 17             6970
# 18            11895
# 19            11459
# 20            12675
# 21            12676
# 22            28563
# 23            29325

# %% [markdown]
# ### 2. NEH

# %% [markdown]
# ### 2.1 Paramétrages

# %%
neh_order_cmax = []
neh_pas_10_cmax = []
neh_pas_20_cmax = []
neh_last_cmax = []
neh_random_cmax = []

neh_order_temps = []
neh_pas_10_temps = []
neh_pas_20_temps = []
neh_last_temps = []
neh_random_temps = []

# %%
#on parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard/"+filename)
    print(filename)
    flowshop = fsp.FlowShop(data)
    
    #NEH order = False
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH(order = False)
    temps_fin = timeit.default_timer() - temps_debut
    neh_order_cmax.append(int(cmax))
    neh_order_temps.append(temps_fin)
    
    #NEH pas = 10
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH(pas = 10)
    temps_fin = timeit.default_timer() - temps_debut
    neh_pas_10_cmax.append(int(cmax))
    neh_pas_10_temps.append(temps_fin)
    
    #NEH pas = 20
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH(pas = 20)
    temps_fin = timeit.default_timer() - temps_debut
    neh_pas_20_cmax.append(int(cmax))
    neh_pas_20_temps.append(temps_fin)
    
    #NEH tie = Last
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH(tie = "Last")
    temps_fin = timeit.default_timer() - temps_debut
    neh_last_cmax.append(int(cmax))
    neh_last_temps.append(temps_fin)
    
    #NEH tie = Random
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH(tie = "Random")
    temps_fin = timeit.default_timer() - temps_debut
    neh_random_cmax.append(int(cmax))
    neh_random_temps.append(temps_fin)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt
# 500jobs_20machines_1.txt
# 500jobs_20machines_2.txt

# %% [markdown]
# #### 2.1.1 CMAX

# %%
print("NEH CMAX - Variation du paramètre : order")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
                   6183,10862,10480,11152,11143,26040,26040],
    "Order = True" : neh_cmax,
    "Order = False" : neh_order_cmax
})
# Out:
# NEH - Variation du paramètre : order
#     jobs  machines  Instance  Best Known  Order = True  Order = False
# 0     20         5         1        1278          1286           1334
# 1     20         5         2        1359          1365           1377
# 2     20        10         1        1582          1680           1675
# 3     20        10         2        1659          1729           1797
# 4     20        20         1        2297          2410           2456
# 5     20        20         2        2099          2150           2197
# 6     50         5         1        2724          2733           2745
# 7     50         5         2        2834          2843           2943
# 8     50        10         1        2991          3135           3249
# 9     50        10         2        2867          3032           3145
# 10    50        20         1        3771          4082           4164
# 11    50        20         2        3668          3921           4020
# 12   100         5         1        5493          5519           5538
# 13   100         5         2        5268          5348           5379
# 14   100        10         1        5770          5846           6027
# 15   100        10         2        5349          5453           5569
# 16   100        20         1        6106          6541           6714
# 17   100        20         2        6183          6523           6620
# 18   200        10         1       10862         10942          11132
# 19   200        10         2       10480         10716          10987
# 20   200        20         1       11152         11594          11759
# 21   200        20         2       11143         11675          11763
# 22   500        20         1       26040         26670          26936
# 23   500        20         2       26040         27232          27396

# %%
print("NEH CMAX - Variation du paramètre : tie")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
                   6183,10862,10480,11152,11143,26040,26040],
    "Tie = First" : neh_cmax,
    "tie = Last" : neh_last_cmax,
    "tie = Random" : neh_random_cmax
})
# Out:
# NEH - Variation du paramètre : tie
#     jobs  machines  Instance  Best Known  Tie = First  tie = Last  \
# 0     20         5         1        1278         1286        1299
# 1     20         5         2        1359         1365        1365
# 2     20        10         1        1582         1680        1681
# 3     20        10         2        1659         1729        1766
# 4     20        20         1        2297         2410        2443
# 5     20        20         2        2099         2150        2134
# 6     50         5         1        2724         2733        2729
# 7     50         5         2        2834         2843        2882
# 8     50        10         1        2991         3135        3175
# 9     50        10         2        2867         3032        3073
# 10    50        20         1        3771         4082        4006
# 11    50        20         2        3668         3921        3958
# 12   100         5         1        5493         5519        5514
# 13   100         5         2        5268         5348        5284
# 14   100        10         1        5770         5846        5897
# 15   100        10         2        5349         5453        5466
# 16   100        20         1        6106         6541        6520
# 17   100        20         2        6183         6523        6550
# 18   200        10         1       10862        10942       10949
# 19   200        10         2       10480        10716       10677
# 20   200        20         1       11152        11594       11638
# 21   200        20         2       11143        11675       11678
# 22   500        20         1       26040        26670       26774
# 23   500        20         2       26040        27232       27215
#
#     tie = Random
# 0           1298
# 1           1377
# 2           1675
# 3           1747
# 4           2443
# 5           2150
# 6           2730
# 7           2848
# 8           3175
# 9           3041
# 10          4105
# 11          3976
# 12          5535
# 13          5294
# 14          5871
# 15          5434
# 16          6571
# 17          6518
# 18         10944
# 19         10636
# 20         11618
# 21         11694
# 22         26719
# 23         27108

# %%
print("NEH CMAX - Variation du paramètre : pas")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Pas = 1" : neh_cmax,
    "Pas = 10" : neh_pas_10_cmax,
    "Pas = 20" : neh_pas_20_cmax
})
# Out:
# NEH CMAX - Variation du paramètre : pas
#     jobs  machines  Instance  Pas = 1  Pas = 10  Pas = 20
# 0     20         5         1     1286      1437      1472
# 1     20         5         2     1365      1476      1517
# 2     20        10         1     1680      1843      2026
# 3     20        10         2     1729      1983      2214
# 4     20        20         1     2410      2599      2937
# 5     20        20         2     2150      2536      2785
# 6     50         5         1     2733      2814      2945
# 7     50         5         2     2843      2990      3042
# 8     50        10         1     3135      3354      3325
# 9     50        10         2     3032      3157      3265
# 10    50        20         1     4082      4494      4760
# 11    50        20         2     3921      4212      4389
# 12   100         5         1     5519      5585      5649
# 13   100         5         2     5348      5351      5480
# 14   100        10         1     5846      6073      6265
# 15   100        10         2     5453      5648      5661
# 16   100        20         1     6541      6877      7128
# 17   100        20         2     6523      6845      7037
# 18   200        10         1    10942     11057     11177
# 19   200        10         2    10716     10865     10960
# 20   200        20         1    11594     11920     12076
# 21   200        20         2    11675     12042     12177
# 22   500        20         1    26670     27007     27089
# 23   500        20         2    27232     27428     27779

# %% [markdown]
# ### 2.1.2 Temps

# %%
print("NEH Temps - Variation du paramètre : order")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Order = True" : neh_temps,
    "Order = False" : neh_order_temps
})
# Out:
# NEH Temps - Variation du paramètre : order
#     jobs  machines  Instance  Order = True  Order = False
# 0     20         5         1      0.048758       0.085476
# 1     20         5         2      0.023793       0.026985
# 2     20        10         1      0.047692       0.051551
# 3     20        10         2      0.045743       0.046960
# 4     20        20         1      0.096272       0.100501
# 5     20        20         2      0.096190       0.096124
# 6     50         5         1      0.336611       0.340077
# 7     50         5         2      0.348529       0.337255
# 8     50        10         1      0.668571       0.718749
# 9     50        10         2      0.664003       0.728352
# 10    50        20         1      1.416315       1.463363
# 11    50        20         2      1.361845       1.442581
# 12   100         5         1      3.197296       2.766709
# 13   100         5         2      2.538651       2.722643
# 14   100        10         1      5.672451       5.798089
# 15   100        10         2      5.921642       5.852662
# 16   100        20         1     11.627239      11.760449
# 17   100        20         2     11.318821      11.648579
# 18   200        10         1     45.171014      46.543516
# 19   200        10         2     43.172243      47.999771
# 20   200        20         1     89.882940      99.471181
# 21   200        20         2     93.528486      98.490028
# 22   500        20         1   1386.202286    1495.861956
# 23   500        20         2   1492.026987    1564.143110

# %%
print("NEH Temps - Variation du paramètre : tie")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Tie = First" : neh_temps,
    "tie = Last" : neh_last_temps,
    "tie = Random" : neh_random_temps
})
# Out:
# NEH Temps - Variation du paramètre : tie
#     jobs  machines  Instance  Tie = First   tie = Last  tie = Random
# 0     20         5         1     0.048758     0.024747      0.024426
# 1     20         5         2     0.023793     0.021546      0.024804
# 2     20        10         1     0.047692     0.045980      0.051967
# 3     20        10         2     0.045743     0.045230      0.048313
# 4     20        20         1     0.096272     0.098725      0.097881
# 5     20        20         2     0.096190     0.103412      0.120610
# 6     50         5         1     0.336611     0.354901      0.346243
# 7     50         5         2     0.348529     0.361571      0.347909
# 8     50        10         1     0.668571     0.697213      0.720990
# 9     50        10         2     0.664003     0.724338      0.690775
# 10    50        20         1     1.416315     1.439432      1.467151
# 11    50        20         2     1.361845     1.447765      1.458367
# 12   100         5         1     3.197296     2.774240      2.703793
# 13   100         5         2     2.538651     2.789606      2.788315
# 14   100        10         1     5.672451     5.750077      5.866491
# 15   100        10         2     5.921642     5.736962      5.776092
# 16   100        20         1    11.627239    12.087113     11.723952
# 17   100        20         2    11.318821    12.079480     11.818896
# 18   200        10         1    45.171014    47.046884     46.566904
# 19   200        10         2    43.172243    48.940121     51.950796
# 20   200        20         1    89.882940    95.484527    113.624037
# 21   200        20         2    93.528486    96.204121    104.797608
# 22   500        20         1  1386.202286  1446.798736   1471.638058
# 23   500        20         2  1492.026987  1477.834268   1443.486059

# %%
print("NEH temps - Variation du paramètre : pas")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Pas = 1" : neh_temps,
    "Pas = 10" : neh_pas_10_temps,
    "Pas = 20" : neh_pas_20_temps
})
# Out:
# NEH - Variation du paramètre : pas
#     jobs  machines  Instance      Pas = 1    Pas = 10   Pas = 20
# 0     20         5         1     0.048758    0.004335   0.002236
# 1     20         5         2     0.023793    0.003201   0.001875
# 2     20        10         1     0.047692    0.005972   0.003218
# 3     20        10         2     0.045743    0.005974   0.003288
# 4     20        20         1     0.096272    0.013807   0.007387
# 5     20        20         2     0.096190    0.013037   0.006700
# 6     50         5         1     0.336611    0.055395   0.025515
# 7     50         5         2     0.348529    0.051755   0.023797
# 8     50        10         1     0.668571    0.081362   0.045154
# 9     50        10         2     0.664003    0.076699   0.047246
# 10    50        20         1     1.416315    0.159036   0.094230
# 11    50        20         2     1.361845    0.163325   0.106174
# 12   100         5         1     3.197296    0.287875   0.149019
# 13   100         5         2     2.538651    0.285087   0.155081
# 14   100        10         1     5.672451    0.611351   0.327705
# 15   100        10         2     5.921642    0.608284   0.311926
# 16   100        20         1    11.627239    1.284853   0.659250
# 17   100        20         2    11.318821    1.270724   0.653897
# 18   200        10         1    45.171014    4.712162   2.461815
# 19   200        10         2    43.172243    4.707645   3.536526
# 20   200        20         1    89.882940    9.645295   5.091552
# 21   200        20         2    93.528486    9.881989   5.207870
# 22   500        20         1  1386.202286  137.166599  74.689264
# 23   500        20         2  1492.026987  148.783853  77.401616

# %% [markdown]
# ### 2.2 Améliorations

# %%
neh_kk2_cmax = []
neh_smm_cmax = []

neh_kk2_temps = []
neh_smm_temps = []

# %%
#on parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard/"+filename)
    print(filename)
    flowshop = fsp.FlowShop(data)
    
    #NEH_ameliore tie = "KK2"
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH_ameliore(tie = "KK2")
    temps_fin = timeit.default_timer() - temps_debut
    neh_kk2_cmax.append(int(cmax))
    neh_kk2_temps.append(temps_fin)
    
    #NEH_ameliore tie = "SMM"
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.NEH_ameliore(tie = "SMM")
    temps_fin = timeit.default_timer() - temps_debut
    neh_smm_cmax.append(int(cmax))
    neh_smm_temps.append(temps_fin)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt
# 500jobs_20machines_1.txt
# 500jobs_20machines_2.txt

# %% [markdown]
# #### 2.2.1 CMAX

# %%
print("NEH Ameliorée : Comparaison par rapport au CMAX")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
                   6183,10862,10480,11152,11143,26040,26040],
    "NEH " : neh_cmax,
    "NEH Ameliorée KK2" : neh_kk2_cmax,
    "NEH Ameliorée SMM" : neh_smm_cmax
})
# Out:
# NEH Ameliorée : Comparaison par rapport au CMAX
#     jobs  machines  Instance  Best Known   NEH   NEH Ameliorée KK2  \
# 0     20         5         1        1278   1286               1342
# 1     20         5         2        1359   1365               1383
# 2     20        10         1        1582   1680               1649
# 3     20        10         2        1659   1729               1716
# 4     20        20         1        2297   2410               2400
# 5     20        20         2        2099   2150               2137
# 6     50         5         1        2724   2733               2724
# 7     50         5         2        2834   2843               2882
# 8     50        10         1        2991   3135               3194
# 9     50        10         2        2867   3032               3039
# 10    50        20         1        3771   4082               4083
# 11    50        20         2        3668   3921               3949
# 12   100         5         1        5493   5519               5538
# 13   100         5         2        5268   5348               5326
# 14   100        10         1        5770   5846               5904
# 15   100        10         2        5349   5453               5478
# 16   100        20         1        6106   6541               6552
# 17   100        20         2        6183   6523               6574
# 18   200        10         1       10862  10942              10926
# 19   200        10         2       10480  10716              10707
# 20   200        20         1       11152  11594              11667
# 21   200        20         2       11143  11675              11691
# 22   500        20         1       26040  26670              26769
# 23   500        20         2       26040  27232              27191
#
#     NEH Ameliorée SMM
# 0                1297
# 1                1383
# 2                1661
# 3                1716
# 4                2401
# 5                2137
# 6                2735
# 7                2882
# 8                3137
# 9                3031
# 10               4007
# 11               3915
# 12               5507
# 13               5318
# 14               5819
# 15               5446
# 16               6575
# 17               6513
# 18              10950
# 19              10623
# 20              11591
# 21              11723
# 22              26704
# 23              27133

# %% [markdown]
# #### 2.2.2 Temps

# %%
print("NEH Ameliorée : Comparaison par rapport au temps d'éxecution")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "NEH " : neh_temps,
    "NEH Ameliorée KK2" : neh_kk2_temps,
    "NEH Ameliorée SMM" : neh_smm_temps
})
# Out:
# NEH Ameliorée : Comparaison par rapport au temps d'éxecution
#     jobs  machines  Instance         NEH   NEH Ameliorée KK2  \
# 0     20         5         1     0.048758           0.121167
# 1     20         5         2     0.023793           0.072284
# 2     20        10         1     0.047692           0.049266
# 3     20        10         2     0.045743           0.054849
# 4     20        20         1     0.096272           0.115469
# 5     20        20         2     0.096190           0.118349
# 6     50         5         1     0.336611           0.364549
# 7     50         5         2     0.348529           0.355497
# 8     50        10         1     0.668571           0.789830
# 9     50        10         2     0.664003           0.728188
# 10    50        20         1     1.416315           1.510058
# 11    50        20         2     1.361845           1.469122
# 12   100         5         1     3.197296           2.819535
# 13   100         5         2     2.538651           2.901192
# 14   100        10         1     5.672451           5.645647
# 15   100        10         2     5.921642           6.080687
# 16   100        20         1    11.627239          11.487070
# 17   100        20         2    11.318821          11.470394
# 18   200        10         1    45.171014          43.807920
# 19   200        10         2    43.172243          46.805665
# 20   200        20         1    89.882940          94.062807
# 21   200        20         2    93.528486          85.061621
# 22   500        20         1  1386.202286        1380.141610
# 23   500        20         2  1492.026987        1357.852928
#
#     NEH Ameliorée SMM
# 0            0.175694
# 1            0.049524
# 2            0.055828
# 3            0.060075
# 4            0.109713
# 5            0.115105
# 6            0.567123
# 7            0.566407
# 8            0.825934
# 9            0.852369
# 10           1.528127
# 11           1.545857
# 12           3.894600
# 13           3.983398
# 14           6.101063
# 15           6.559289
# 16          12.281684
# 17          11.682565
# 18          57.375699
# 19          52.683192
# 20         100.774752
# 21          94.615474
# 22        1458.964201
# 23        1319.678684

# %% [markdown]
# # 3 Palmer

# %%
palmer_mpi_cmax=[]
palmer_mpi_temps=[]
palmer_temps = []

# %%
#on parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard/"+filename)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    
    #Palmer
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.palmer_heuristic()
    temps_fin = timeit.default_timer() - temps_debut
    palmer_temps.append(temps_fin)
    
    #palmer_amélioré
    temps_debut = timeit.default_timer()
    sigma, cmax = flowshop.Palmer_MPI()
    temps_fin = timeit.default_timer() - temps_debut
    palmer_mpi_cmax.append(int(cmax))
    palmer_mpi_temps.append(temps_fin)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt
# 500jobs_20machines_1.txt
# 500jobs_20machines_2.txt

# %% [markdown]
# #### 3.1 CMAX

# %%
print("Palmer Ameliorée : Comparaison par rapport au temps d'éxecution")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
                   6183,10862,10480,11152,11143,26040,26040],
    "palmer " : palmer_cmax,
    "palmer Ameliorée" : palmer_mpi_cmax
})
# Out:
# Palmer Ameliorée : Comparaison par rapport au temps d'éxecution
#     jobs  machines  Instance  Best Known  palmer   palmer Ameliorée
# 0     20         5         1        1278     1384              1384
# 1     20         5         2        1359     1439              1437
# 2     20        10         1        1582     1790              1741
# 3     20        10         2        1659     1948              1894
# 4     20        20         1        2297     2818              2809
# 5     20        20         2        2099     2331              2316
# 6     50         5         1        2724     2774              2774
# 7     50         5         2        2834     3014              2957
# 8     50        10         1        2991     3453              3453
# 9     50        10         2        2867     3313              3196
# 10    50        20         1        3771     4272              4272
# 11    50        20         2        3668     4303              4303
# 12   100         5         1        5493     5749              5593
# 13   100         5         2        5268     5316              5316
# 14   100        10         1        5770     6161              6161
# 15   100        10         2        5349     5889              5773
# 16   100        20         1        6106     7075              7075
# 17   100        20         2        6183     7058              7058
# 18   200        10         1       10862    11443             11407
# 19   200        10         2       10480    10986             10986
# 20   200        20         1       11152    13042             12896
# 21   200        20         2       11143    12813             12726
# 22   500        20         1       26040    28246             28013
# 23   500        20         2       26040    29439             29439

# %% [markdown]
# #### 3.2 Temps

# %%
print("Palmer Ameliorée : Comparaison par rapport au temps d'éxecution")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "palmer " : palmer_temps,
    "palmer Ameliorée" : palmer_mpi_temps
})
# Out:
# Palmer Ameliorée : Comparaison par rapport au temps d'éxecution
#     jobs  machines  Instance   palmer   palmer Ameliorée
# 0     20         5         1  0.003241          0.009974
# 1     20         5         2  0.003055          0.008983
# 2     20        10         1  0.005219          0.013654
# 3     20        10         2  0.002104          0.006367
# 4     20        20         1  0.009619          0.014975
# 5     20        20         2  0.003042          0.009205
# 6     50         5         1  0.000873          0.004175
# 7     50         5         2  0.001411          0.004800
# 8     50        10         1  0.002039          0.005003
# 9     50        10         2  0.002577          0.007224
# 10    50        20         1  0.002737          0.008623
# 11    50        20         2  0.003564          0.009606
# 12   100         5         1  0.001309          0.005441
# 13   100         5         2  0.001514          0.004534
# 14   100        10         1  0.003842          0.014385
# 15   100        10         2  0.002686          0.008352
# 16   100        20         1  0.006283          0.018508
# 17   100        20         2  0.005219          0.017135
# 18   200        10         1  0.006565          0.020743
# 19   200        10         2  0.006468          0.016206
# 20   200        20         1  0.011855          0.036318
# 21   200        20         2  0.010529          0.043056
# 22   500        20         1  0.029421          0.096150
# 23   500        20         2  0.030865          0.093909

# %% [markdown]
# # Meta heurestiques

# %% [markdown]
# ## 1.Recuit Simulé

# %% [markdown]
# ## Etude parametrique

# %% [markdown]
# ## 1.1 La strategie de generation de voisinage

# %%
recuit_simule_insertion_cmax=[]
recuit_simule_swap_cmax=[]
recuit_simule_interchange_cmax=[]
machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #Voisinage = Insertion 
    sigma, cmax = flowshop.recuit_simule()
    recuit_simule_insertion_cmax.append(int(cmax))
    
    #Voisinage = Swap 
    sigma, cmax = flowshop.recuit_simule(voisinage = "Swap")
    recuit_simule_swap_cmax.append(int(cmax))
    
    #Voisinage = Interchange 
    sigma, cmax = flowshop.recuit_simule(voisinage = "Interchange")
    recuit_simule_interchange_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Recuit Simule : Comparaison du Cmax par rapport a la strategie de generation de voisinage")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "Voisinage = Insertion" : recuit_simule_insertion_cmax,
    "Voisinage = Swap" : recuit_simule_swap_cmax,
    "Voisinage = Interchange" : recuit_simule_interchange_cmax
    
})
# Out:
# Recuit Simule : Comparaison du Cmax par rapport a la strategie de generation de voisinage
#     jobs  machines  Instance  Best Known  Voisinage = Insertion  \
# 0     20         5         1        1278                   1470
# 1     20         5         2        1359                   1446
# 2     20        10         1        1582                   1917
# 3     20        10         2        1659                   1964
# 4     20        20         1        2297                   2567
# 5     20        20         2        2099                   2420
# 6     50         5         1        2724                   2876
# 7     50         5         2        2834                   3172
# 8     50        10         1        2991                   3569
# 9     50        10         2        2867                   3228
# 10    50        20         1        3771                   4661
# 11    50        20         2        3668                   4286
# 12   100         5         1        5493                   5761
# 13   100         5         2        5268                   5612
# 14   100        10         1        5770                   6003
# 15   100        10         2        5349                   5968
# 16   100        20         1        6106                   7196
# 17   100        20         2        6183                   7149
# 18   200        10         1       10862                  11314
# 19   200        10         2       10480                  11033
# 20   200        20         1       11152                  12252
# 21   200        20         2       11143                  12149
#
#     Voisinage = Swap  Voisinage = Interchange
# 0               1343                     1375
# 1               1424                     1463
# 2               1788                     1875
# 3               1847                     1994
# 4               2409                     2610
# 5               2339                     2456
# 6               2735                     2859
# 7               2957                     3218
# 8               3269                     3537
# 9               3054                     3600
# 10              4263                     4474
# 11              4051                     4509
# 12              5548                     5979
# 13              5433                     5721
# 14              5986                     6570
# 15              5560                     5976
# 16              6777                     7004
# 17              6672                     7127
# 18             10963                    11347
# 19             10717                    11306
# 20             11717                    12295
# 21             11892                    12814

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(recuit_simule_insertion_cmax)
plt.plot(ypoints1, color = 'r', label = "Voisinage = Insertion")

ypoints2 = np.array(recuit_simule_swap_cmax)
plt.plot(ypoints2, color = 'b', label = "Voisinage = Swap")

ypoints3 = np.array(recuit_simule_interchange_cmax)
plt.plot(ypoints3, color = 'g', label = "Voisinage = Interchange")

plt.legend();
plt.ylabel("Cmax");
plt.title("Recuit Simule : Comparaison du Cmax par rapport a la strategie de generation de voisinage")
plt.show()

# %% [markdown]
# ## 1.2 La strategie de mise à jour de la temperature

# %%
recuit_simule_geo_cmax=[]
recuit_simule_linear_cmax=[]
recuit_simule_slow_cmax=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    print(filename)
    
    flowshop = fsp.FlowShop(data)
    
    #Voisinage = Insertion 
    sigma, cmax = flowshop.recuit_simule()
    recuit_simule_geo_cmax.append(int(cmax))
    
    #Voisinage = Swap 
    sigma, cmax = flowshop.recuit_simule(TempUpdate = "Linear")
    recuit_simule_linear_cmax.append(int(cmax))
    
    #Voisinage = Interchange 
    sigma, cmax = flowshop.recuit_simule(TempUpdate = "Slow")
    recuit_simule_slow_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Recuit Simule : Comparaison du Cmax par rapport a la strategie de mise à jour de la temperature")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "Fonction = Geometrique" : recuit_simule_geo_cmax,
    "Fonction = Linear" : recuit_simule_linear_cmax,
    "Fonction = Slow" : recuit_simule_slow_cmax
    
})
# Out:
# Recuit Simule : Comparaison du Cmax par rapport a la strategie de mise à jour de la temperature
#     jobs  machines  Instance  Best Known  Fonction = Geometrique  \
# 0     20         5         1        1278                    1471
# 1     20         5         2        1359                    1436
# 2     20        10         1        1582                    1918
# 3     20        10         2        1659                    1902
# 4     20        20         1        2297                    2664
# 5     20        20         2        2099                    2472
# 6     50         5         1        2724                    2914
# 7     50         5         2        2834                    3158
# 8     50        10         1        2991                    3487
# 9     50        10         2        2867                    3359
# 10    50        20         1        3771                    4457
# 11    50        20         2        3668                    4268
# 12   100         5         1        5493                    5841
# 13   100         5         2        5268                    5653
# 14   100        10         1        5770                    6298
# 15   100        10         2        5349                    5891
# 16   100        20         1        6106                    7081
# 17   100        20         2        6183                    6997
# 18   200        10         1       10862                   11446
# 19   200        10         2       10480                   11151
# 20   200        20         1       11152                   12284
# 21   200        20         2       11143                   12214
#
#     Fonction = Linear  Fonction = Slow
# 0                1428             1307
# 1                1424             1401
# 2                1852             1649
# 3                2016             1790
# 4                2686             2453
# 5                2466             2139
# 6                2964             2735
# 7                3304             2882
# 8                3530             3165
# 9                3786             3095
# 10               4846             4007
# 11               4584             3981
# 12               5901             5507
# 13               5877             5318
# 14               6772             5819
# 15               6448             5500
# 16               7511             6676
# 17               7722             6577
# 18              12216            10950
# 19              11970            10623
# 20              13583            11619
# 21              13798            11805

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(recuit_simule_geo_cmax)
plt.plot(ypoints1, color = 'r', label = "Fonction = Geometrique")

ypoints2 = np.array(recuit_simule_linear_cmax)
plt.plot(ypoints2, color = 'b', label = "Fonction = Linear")

ypoints3 = np.array(recuit_simule_slow_cmax)
plt.plot(ypoints3, color = 'g', label = "Fonction = Slow")

plt.legend();
plt.ylabel("Cmax");
plt.title("Recuit Simule : Comparaison du Cmax par rapport au nombre de palier")
plt.show()

# %% [markdown]
# ## 1.3 Le nombre de paliers

# %%
recuit_simule_palier_1_cmax=[]
recuit_simule_palier_5_cmax=[]
recuit_simule_palier_10_cmax=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    print(filename)
    
    flowshop = fsp.FlowShop(data)
    
    #Palier = 1
    sigma, cmax = flowshop.recuit_simule()
    recuit_simule_palier_1_cmax.append(int(cmax))
    
    #Palier = 5
    sigma, cmax = flowshop.recuit_simule(palier = 5)
    recuit_simule_palier_5_cmax.append(int(cmax))
    
    #Palier = 10
    sigma, cmax = flowshop.recuit_simule(palier = 10)
    recuit_simule_palier_10_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Recuit Simule : Comparaison du Cmax par rapport au nombre de palier")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "Nb paliers = 1" : recuit_simule_palier_1_cmax,
    "Nb paliers = 5" : recuit_simule_palier_5_cmax,
    "Nb paliers = 10" : recuit_simule_palier_10_cmax
    
})
# Out:
# Recuit Simule : Comparaison du Cmax par rapport au nombre de palier
#     jobs  machines  Instance  Best Known  Nb paliers = 1  Nb paliers = 5  \
# 0     20         5         1        1278            1430            1416
# 1     20         5         2        1359            1516            1424
# 2     20        10         1        1582            1918            1867
# 3     20        10         2        1659            1947            1858
# 4     20        20         1        2297            2630            2665
# 5     20        20         2        2099            2394            2459
# 6     50         5         1        2724            3024            2854
# 7     50         5         2        2834            3099            3217
# 8     50        10         1        2991            3511            3561
# 9     50        10         2        2867            3396            3407
# 10    50        20         1        3771            4400            4686
# 11    50        20         2        3668            4385            4542
# 12   100         5         1        5493            5735            5938
# 13   100         5         2        5268            5582            5779
# 14   100        10         1        5770            6266            6649
# 15   100        10         2        5349            5684            6280
# 16   100        20         1        6106            6891            7731
# 17   100        20         2        6183            7131            7528
# 18   200        10         1       10862           11275           11973
# 19   200        10         2       10480           11231           11373
# 20   200        20         1       11152           12049           12643
# 21   200        20         2       11143           11999           13061
#
#     Nb paliers = 10
# 0              1392
# 1              1437
# 2              1894
# 3              1883
# 4              2602
# 5              2272
# 6              3034
# 7              3244
# 8              3629
# 9              3398
# 10             4651
# 11             4559
# 12             5925
# 13             5770
# 14             6657
# 15             6036
# 16             7572
# 17             7737
# 18            12088
# 19            11813
# 20            13210
# 21            13507

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(recuit_simule_palier_1_cmax)
plt.plot(ypoints1, color = 'r', label = "Nb paliers = 1")

ypoints2 = np.array(recuit_simule_palier_5_cmax)
plt.plot(ypoints2, color = 'b', label = "Nb paliers = 5")

ypoints3 = np.array(recuit_simule_palier_10_cmax)
plt.plot(ypoints3, color = 'g', label = "Nb paliers = 10")

plt.legend();
plt.ylabel("Cmax");
plt.title("Recuit Simule : Comparaison du Cmax par rapport au nombre de palier")
plt.show()

# %% [markdown]
# ## 1.4 Le nombre maximal de solution rejetées

# %%
recuit_simule_nbsolrej_Infini_cmax= recuit_simule_palier_1_cmax
recuit_simule_nbsolrej_50_cmax= []
recuit_simule_nbsolrej_10_cmax= []

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    print(filename)
    
    flowshop = fsp.FlowShop(data)
    
    #nbsolrej = 50
    sigma, cmax = flowshop.recuit_simule(nbsolrej = 5)
    recuit_simule_nbsolrej_50_cmax.append(int(cmax))
    
    #nbsolrej = 10
    sigma, cmax = flowshop.recuit_simule(nbsolrej = 10)
    recuit_simule_nbsolrej_10_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Recuit Simule : Comparaison du Cmax par rapport au nombre maximal de solutions rejetees")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "nbsolrej = Infini" : recuit_simule_nbsolrej_Infini_cmax,
    "nbsolrej = 50" : recuit_simule_nbsolrej_50_cmax,
    "nbsolrej = 10" : recuit_simule_nbsolrej_10_cmax
    
})
# Out:
# Recuit Simule : Comparaison du Cmax par rapport au nombre maximal de solutions rejetees
#     jobs  machines  Instance  Best Known  nbsolrej = Infini  nbsolrej = 50  \
# 0     20         5         1        1278               1430           1451
# 1     20         5         2        1359               1516           1458
# 2     20        10         1        1582               1918           1827
# 3     20        10         2        1659               1947           2022
# 4     20        20         1        2297               2630           2534
# 5     20        20         2        2099               2394           2418
# 6     50         5         1        2724               3024           2900
# 7     50         5         2        2834               3099           3194
# 8     50        10         1        2991               3511           3595
# 9     50        10         2        2867               3396           3527
# 10    50        20         1        3771               4400           4561
# 11    50        20         2        3668               4385           4529
# 12   100         5         1        5493               5735           6111
# 13   100         5         2        5268               5582           5862
# 14   100        10         1        5770               6266           6707
# 15   100        10         2        5349               5684           6835
# 16   100        20         1        6106               6891           7696
# 17   100        20         2        6183               7131           7581
# 18   200        10         1       10862              11275          12479
# 19   200        10         2       10480              11231          11917
# 20   200        20         1       11152              12049          13491
# 21   200        20         2       11143              11999          13154
#
#     nbsolrej = 10
# 0            1416
# 1            1526
# 2            1923
# 3            2017
# 4            2613
# 5            2473
# 6            3200
# 7            3253
# 8            3583
# 9            3745
# 10           4807
# 11           4467
# 12           5988
# 13           5885
# 14           6682
# 15           6288
# 16           7347
# 17           7504
# 18          11915
# 19          11544
# 20          12941
# 21          13996

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(recuit_simule_nbsolrej_Infini_cmax)
plt.plot(ypoints1, color = 'r', label = "nbsolrej = Infini")

ypoints2 = np.array(recuit_simule_nbsolrej_50_cmax)
plt.plot(ypoints2, color = 'b', label = "nbsolrej = 50")

ypoints3 = np.array(recuit_simule_nbsolrej_10_cmax)
plt.plot(ypoints3, color = 'g', label = "nbsolrej = 10")

plt.legend();
plt.ylabel("Cmax");
plt.title("Recuit Simule : Comparaison du Cmax par rapport au nombre maximal de solutions rejetees")
plt.show()

# %% [markdown]
# ## 1.5 Variation du parametre alpha

# %%
recuit_simule_alpha_09_cmax= recuit_simule_palier_1_cmax
recuit_simule_alpha_05_cmax= []
recuit_simule_alpha_01_cmax= []

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    print(filename)
    
    flowshop = fsp.FlowShop(data)
    
    #alpha = 0.5
    sigma, cmax = flowshop.recuit_simule(alpha = 0.5)
    recuit_simule_alpha_05_cmax.append(int(cmax))
    
    #alpha = 0.1
    sigma, cmax = flowshop.recuit_simule(alpha = 0.1)
    recuit_simule_alpha_01_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Recuit Simule : Comparaison du Cmax en variant alpha")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "alpha = 0.9" : recuit_simule_alpha_09_cmax,
    "alpha = 0.5" : recuit_simule_alpha_05_cmax,
    "alpha = 0.1" : recuit_simule_alpha_01_cmax
    
})
# Out:
# Recuit Simule : Comparaison du Cmax en variant alpha
#     jobs  machines  Instance  Best Known  alpha = 0.9  alpha = 0.5  \
# 0     20         5         1        1278         1430         1300
# 1     20         5         2        1359         1516         1383
# 2     20        10         1        1582         1918         1843
# 3     20        10         2        1659         1947         1716
# 4     20        20         1        2297         2630         2593
# 5     20        20         2        2099         2394         2352
# 6     50         5         1        2724         3024         2825
# 7     50         5         2        2834         3099         2952
# 8     50        10         1        2991         3511         3245
# 9     50        10         2        2867         3396         3100
# 10    50        20         1        3771         4400         4107
# 11    50        20         2        3668         4385         3953
# 12   100         5         1        5493         5735         5552
# 13   100         5         2        5268         5582         5338
# 14   100        10         1        5770         6266         5929
# 15   100        10         2        5349         5684         5486
# 16   100        20         1        6106         6891         6682
# 17   100        20         2        6183         7131         6802
# 18   200        10         1       10862        11275        10973
# 19   200        10         2       10480        11231        10648
# 20   200        20         1       11152        12049        11760
# 21   200        20         2       11143        11999        11778
#
#     alpha = 0.1
# 0          1339
# 1          1383
# 2          1727
# 3          1737
# 4          2401
# 5          2138
# 6          2735
# 7          2882
# 8          3211
# 9          3033
# 10         4171
# 11         3915
# 12         5555
# 13         5318
# 14         5862
# 15         5473
# 16         6686
# 17         6535
# 18        10950
# 19        10653
# 20        11611
# 21        11826

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(recuit_simule_alpha_09_cmax)
plt.plot(ypoints1, color = 'r', label = "alpha = 0.9")

ypoints2 = np.array(recuit_simule_alpha_05_cmax)
plt.plot(ypoints2, color = 'b', label = "alpha = 0.5")

ypoints3 = np.array(recuit_simule_alpha_01_cmax)
plt.plot(ypoints3, color = 'g', label = "alpha = 0.1")

plt.legend();
plt.ylabel("Cmax");
plt.title("Recuit Simule : Comparaison du Cmax en variant alpha")
plt.show()

# %% [markdown]
# ## 2.Iterative Local Search

# %% [markdown]
# ## Etude parametrique

# %% [markdown]
# ## 2.1. Generation du voisinage

# %%
ils_insertion_cmax=[]
ils_swap_cmax=[]
ils_interchange_cmax=[]
machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #Voisinage = Insertion 
    sigma, cmax = flowshop.ILS()
    ils_insertion_cmax.append(int(cmax))
    
    #Voisinage = Swap 
    sigma, cmax = flowshop.ILS(neibourhoodType = "Swap")
    ils_swap_cmax.append(int(cmax))
    
    #Voisinage = Interchange 
    sigma, cmax = flowshop.ILS(neibourhoodType = "Interchange")
    ils_interchange_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Iterative Local Search : Comparaison du Cmax par rapport a la strategie de generation de voisinage")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "Voisinage = Insertion" : ils_insertion_cmax,
    "Voisinage = Swap" : ils_swap_cmax,
    "Voisinage = Interchange" : ils_interchange_cmax
    
})
# Out:
# Iterative Local Search : Comparaison du Cmax par rapport a la strategie de generation de voisinage
#     jobs  machines  Instance  Best Known  Voisinage = Insertion  \
# 0     20         5         1        1278                   1297
# 1     20         5         2        1359                   1383
# 2     20        10         1        1582                   1642
# 3     20        10         2        1659                   1712
# 4     20        20         1        2297                   2386
# 5     20        20         2        2099                   2125
# 6     50         5         1        2724                   2735
# 7     50         5         2        2834                   2882
# 8     50        10         1        2991                   3133
# 9     50        10         2        2867                   3025
# 10    50        20         1        3771                   4002
# 11    50        20         2        3668                   3915
# 12   100         5         1        5493                   5498
# 13   100         5         2        5268                   5318
# 14   100        10         1        5770                   5819
# 15   100        10         2        5349                   5442
# 16   100        20         1        6106                   6573
# 17   100        20         2        6183                   6497
# 18   200        10         1       10862                  10950
# 19   200        10         2       10480                  10617
# 20   200        20         1       11152                  11576
# 21   200        20         2       11143                  11712
#
#     Voisinage = Swap  Voisinage = Interchange
# 0               1297                     1297
# 1               1383                     1383
# 2               1661                     1661
# 3               1716                     1716
# 4               2401                     2401
# 5               2137                     2137
# 6               2735                     2735
# 7               2882                     2882
# 8               3137                     3137
# 9               3031                     3031
# 10              4007                     4007
# 11              3915                     3915
# 12              5507                     5507
# 13              5318                     5318
# 14              5819                     5819
# 15              5446                     5446
# 16              6575                     6575
# 17              6513                     6513
# 18             10950                    10950
# 19             10623                    10623
# 20             11591                    11591
# 21             11723                    11723

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(ils_insertion_cmax)
plt.plot(ypoints1, color = 'r', label = "Voisinage = Insertion")

ypoints2 = np.array(ils_swap_cmax)
plt.plot(ypoints2, color = 'b', label = "Voisinage = Swap")

ypoints3 = np.array(ils_interchange_cmax)
plt.plot(ypoints3, color = 'g', label = "Voisinage = Interchange")

plt.legend();
plt.ylabel("Cmax");
plt.title("ILS : Comparaison du Cmax par rapport a la strategie de generation de voisinage")
plt.show()

# %% [markdown]
# ## 2.2. Stratégie de selection dans le voisinage

# %%
ils_best_cmax=[]
ils_first_cmax=[]
machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #Selection = Best
    sigma, cmax = flowshop.ILS(selectionStrategy = 'best')
    ils_best_cmax.append(int(cmax))
    
    #Selection = First
    sigma, cmax = flowshop.ILS(selectionStrategy = 'first')
    ils_first_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Iterative Local Search : Comparaison du Cmax par rapport a la strategie de selection dans voisinage")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "Selection = best" : ils_best_cmax,
    "Selection = first" : ils_first_cmax
    
})
# Out:
# Iterative Local Search : Comparaison du Cmax par rapport a la strategie de selection dans voisinage
#     jobs  machines  Instance  Best Known  Selection = best  Selection = first
# 0     20         5         1        1278              1297               1297
# 1     20         5         2        1359              1383               1383
# 2     20        10         1        1582              1642               1658
# 3     20        10         2        1659              1712               1712
# 4     20        20         1        2297              2386               2400
# 5     20        20         2        2099              2125               2125
# 6     50         5         1        2724              2735               2735
# 7     50         5         2        2834              2882               2882
# 8     50        10         1        2991              3133               3133
# 9     50        10         2        2867              3025               3025
# 10    50        20         1        3771              4002               4002
# 11    50        20         2        3668              3915               3915
# 12   100         5         1        5493              5498               5502
# 13   100         5         2        5268              5318               5318
# 14   100        10         1        5770              5819               5819
# 15   100        10         2        5349              5442               5442
# 16   100        20         1        6106              6573               6573
# 17   100        20         2        6183              6497               6511
# 18   200        10         1       10862             10950              10950
# 19   200        10         2       10480             10617              10621
# 20   200        20         1       11152             11576              11588
# 21   200        20         2       11143             11712              11722

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(ils_best_cmax)
plt.plot(ypoints1, color = 'r', label = "Selection = Best")

ypoints2 = np.array(ils_first_cmax)
plt.plot(ypoints2, color = 'b', label = "Selection = First")

plt.legend();
plt.ylabel("Cmax");
plt.title("ILS : Comparaison du Cmax par rapport a la strategie de selection dans le voisinage")
plt.show()

# %% [markdown]
# ## 2.3. Stratégie de perturbation dans le voisinage

# %%
ils_insertion_cmax=[]
ils_swap_cmax=[]
ils_random_cmax=[]
machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #Perturbation = Insertion
    sigma, cmax = flowshop.ILS(perturbationType = "insertion", maxCriteria = 1)
    ils_insertion_cmax.append(int(cmax))
    
    #Perturbation = Swap 
    sigma, cmax = flowshop.ILS(perturbationType = "Swap", maxCriteria = 1)
    ils_swap_cmax.append(int(cmax))
    
    #Perturbation = Random
    sigma, cmax = flowshop.ILS(perturbationType = "random", maxCriteria = 1)
    ils_random_cmax.append(int(cmax))
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Iterative Local Search : Comparaison du Cmax par rapport a la strategie de perturbation")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1582,1659,2297,2099,2724,2834,2991,2867,3771,3668,5493,5268,5770,5349,6106,
               6183,10862,10480,11152,11143],
    "Perturbation = Insertion" : ils_insertion_cmax,
    "Perturbation = Swap" : ils_swap_cmax,
    "Perturbation = Random" : ils_random_cmax
    
})
# Out:
# Iterative Local Search : Comparaison du Cmax par rapport a la strategie de perturbation
#     jobs  machines  Instance  Best Known  Perturbation = Insertion  \
# 0     20         5         1        1278                      1297
# 1     20         5         2        1359                      1383
# 2     20        10         1        1582                      1642
# 3     20        10         2        1659                      1712
# 4     20        20         1        2297                      2386
# 5     20        20         2        2099                      2125
# 6     50         5         1        2724                      2735
# 7     50         5         2        2834                      2882
# 8     50        10         1        2991                      3133
# 9     50        10         2        2867                      3025
# 10    50        20         1        3771                      4002
# 11    50        20         2        3668                      3915
# 12   100         5         1        5493                      5498
# 13   100         5         2        5268                      5318
# 14   100        10         1        5770                      5819
# 15   100        10         2        5349                      5442
# 16   100        20         1        6106                      6573
# 17   100        20         2        6183                      6497
# 18   200        10         1       10862                     10950
# 19   200        10         2       10480                     10617
# 20   200        20         1       11152                     11567
# 21   200        20         2       11143                     11712
#
#     Perturbation = Swap  Perturbation = Random
# 0                  1297                   1297
# 1                  1383                   1383
# 2                  1635                   1642
# 3                  1712                   1712
# 4                  2386                   2386
# 5                  2125                   2125
# 6                  2735                   2735
# 7                  2882                   2882
# 8                  3133                   3133
# 9                  3025                   3025
# 10                 4002                   4002
# 11                 3915                   3915
# 12                 5498                   5498
# 13                 5318                   5318
# 14                 5819                   5819
# 15                 5434                   5442
# 16                 6573                   6573
# 17                 6492                   6497
# 18                10950                  10950
# 19                10611                  10617
# 20                11570                  11576
# 21                11712                  11712

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(ils_insertion_cmax)
plt.plot(ypoints1, color = 'r', label = "Perturbation = Insertion")

ypoints2 = np.array(ils_swap_cmax)
plt.plot(ypoints2, color = 'b', label = "Perturbation = Swap")

ypoints3 = np.array(ils_random_cmax)
plt.plot(ypoints3, color = 'g', label = "Perturbation = Random")

plt.legend();
plt.ylabel("Cmax");
plt.title("ILS : Comparaison du Cmax par rapport a la strategie de perturbation")
plt.show()

# %% [markdown]
# ## 2.4. Citere d'arret - Propriété Anytime

# %%
ils_duration_cmax=[]
files=os.listdir("./Instances_Taillard2")

for i in range(1, 10):
    filename = "050jobs_10machines_2.txt"
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    print(filename)
    
    flowshop = fsp.FlowShop(data)
    
    #Perturbation = Insertion
    sigma, cmax = flowshop.ILS(neibourhoodType='interchange', selectionStrategy = 'best', perturbationType='swap', 
                               stopCriteria = 'duration', maxCriteria = i)
    ils_duration_cmax.append(int(cmax))
# Out:
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt
# 050jobs_10machines_2.txt

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(ils_duration_cmax)
plt.plot(ypoints1, color = 'r', label = "Evolution de Cmax en fct de la duree (en sec)")

plt.legend();
plt.ylabel("Cmax");
plt.title("ILS : Evolution de Cmax en fonction de la duree d'execution")
plt.show()

# %% [markdown]
# ## 2.5. Strategie de selection et le temps d'execution

# %%
ils_best_temps=[]
ils_first_temps=[]
machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #Selection = Best
    start = timeit.default_timer()
    sigma, cmax = flowshop.ILS(neibourhoodType='swap', selectionStrategy = 'best', maxCriteria = 10)
    ils_best_temps.append(timeit.default_timer()-start)
    
    #Selection = First
    start = timeit.default_timer()
    sigma, cmax = flowshop.ILS(neibourhoodType='swap', selectionStrategy = 'first', maxCriteria = 10)
    ils_first_temps.append(timeit.default_timer()-start)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt
# 100jobs_05machines_1.txt
# 100jobs_05machines_2.txt
# 100jobs_10machines_1.txt
# 100jobs_10machines_2.txt
# 100jobs_20machines_1.txt
# 100jobs_20machines_2.txt
# 200jobs_10machines_1.txt
# 200jobs_10machines_2.txt
# 200jobs_20machines_1.txt
# 200jobs_20machines_2.txt

# %%
print("Iterative Local Search : Comparaison du temps par rapport a la strategie de selection dans voisinage")

pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Selection = best" : ils_best_temps,
    "Selection = first" : ils_first_temps
    
})
# Out:
# Iterative Local Search : Comparaison du temps par rapport a la strategie de selection dans voisinage
#     jobs  machines  Instance  Selection = best  Selection = first
# 0     20         5         1          0.063776           0.047412
# 1     20         5         2          0.059639           0.050799
# 2     20        10         1          0.090543           0.059340
# 3     20        10         2          0.087647           0.050907
# 4     20        20         1          0.181930           0.097809
# 5     20        20         2          0.290234           0.108251
# 6     50         5         1          0.552627           0.510732
# 7     50         5         2          0.517406           0.428884
# 8     50        10         1          0.853142           0.611803
# 9     50        10         2          0.878393           0.690237
# 10    50        20         1          1.830723           1.010916
# 11    50        20         2          1.198303           0.882426
# 12   100         5         1          2.396029           2.133448
# 13   100         5         2          2.294495           1.966493
# 14   100        10         1          3.884350           3.693251
# 15   100        10         2          3.906204           3.427110
# 16   100        20         1          7.501342           6.127981
# 17   100        20         2          7.567182           5.818474
# 18   200        10         1         30.721945          31.237281
# 19   200        10         2         32.263795          25.681506
# 20   200        20         1         54.043654          48.344907
# 21   200        20         2         56.597466          46.857351

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(ils_best_temps)
plt.plot(ypoints1, color = 'r', label = "Selection = Best")

ypoints2 = np.array(ils_first_temps)
plt.plot(ypoints2, color = 'b', label = "Selection = First")

plt.legend();
plt.ylabel("Temps");
plt.title("ILS : Comparaison du Temps par rapport a la strategie de selection dans le voisinage")
plt.show()

# %% [markdown]
# ## 3.Genetic Algorithm

# %% [markdown]
# ## Etude paramétrique

# %% [markdown]
# ## 3.1. Techniques de selection des parents:

# %%
GA_temps=[]
GA_Cmax_tournois=[]
GA_Cmax_random=[]
GA_Cmax_elit=[]
GA_Cmax_roulette=[]
GA_Cmax_ranking=[]

GA_temp_tournois=[]
GA_temp_random=[]
GA_temp_elit=[]
GA_temp_roulette=[]
GA_temp_ranking=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_parent_selection="tournois")
    GA_temp_tournois.append(timeit.default_timer()-start)
    GA_Cmax_tournois.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_parent_selection="random")
    GA_temp_random.append(timeit.default_timer()-start)
    GA_Cmax_random.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_parent_selection="elit")
    GA_temp_elit.append(timeit.default_timer()-start)
    GA_Cmax_elit.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_parent_selection="roulette")
    GA_temp_roulette.append(timeit.default_timer()-start)
    GA_Cmax_roulette.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_parent_selection="ranking")
    GA_temp_ranking.append(timeit.default_timer()-start)
    GA_Cmax_ranking.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Techniques de selection des parents")
print("Cmax|Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : Best_known[:12],
   "tournois" : GA_Cmax_tournois,
    "random" : GA_Cmax_random,
    "elit":GA_Cmax_elit,
    "roulette":GA_Cmax_roulette,
    "ranking":GA_Cmax_ranking

})
# Out:
# Techniques de selection des parents
# Cmax|Temps
#     jobs  machines  Instance  Best Known  tournois  random    elit  roulette  \
# 0     20         5         1        1278    1297.0  1297.0  1297.0    1297.0
# 1     20         5         2        1359    1383.0  1383.0  1383.0    1383.0
# 2     20        10         1        1582    1628.0  1628.0  1635.0    1628.0
# 3     20        10         2        1659    1705.0  1705.0  1705.0    1705.0
# 4     20        20         1        2297    2365.0  2365.0  2365.0    2365.0
# 5     20        20         2        2099    2165.0  2165.0  2165.0    2165.0
# 6     50         5         1        2724    2729.0  2729.0  2729.0    2729.0
# 7     50         5         2        2834    2882.0  2882.0  2882.0    2882.0
# 8     50        10         1        2991    3132.0  3132.0  3132.0    3132.0
# 9     50        10         2        2867    2995.0  2995.0  2994.0    2994.0
# 10    50        20         1        3771    4027.0  4026.0  4026.0    4027.0
# 11    50        20         2        3668    3868.0  3868.0  3884.0    3868.0
#
#     ranking
# 0    1297.0
# 1    1383.0
# 2    1622.0
# 3    1705.0
# 4    2365.0
# 5    2165.0
# 6    2729.0
# 7    2882.0
# 8    3137.0
# 9    2995.0
# 10   4027.0
# 11   3868.0

# %%
print("Techniques de selection des parents")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "tournois" : GA_temp_tournois,
    "random" : GA_temp_random,
    "elit":GA_temp_elit,
    "roulette":GA_temp_roulette,
    "ranking":GA_temp_ranking

})
# Out:
# Techniques de selection des parents
# Temps
#     jobs  machines  Instance    tournois      random        elit    roulette  \
# 0     20         5         1    8.295654    5.923328    8.293058    8.229025
# 1     20         5         2    8.109969    6.026232    8.200391    8.399524
# 2     20        10         1   21.237282   15.581483   15.362625   22.524463
# 3     20        10         2   20.300380   13.721506   18.117498   20.137837
# 4     20        20         1   36.131843   25.794890   32.393293   33.866566
# 5     20        20         2   39.138749   29.336981   31.647128   34.353094
# 6     50         5         1   24.256760   20.456979   25.613701   28.230288
# 7     50         5         2   23.027137   16.647583   21.836118   22.016000
# 8     50        10         1   68.643938   63.360578   70.483604   71.073310
# 9     50        10         2   56.533084   42.492100   88.836396  112.997785
# 10    50        20         1  137.084057  138.298850  125.202145  132.082821
# 11    50        20         2  236.785192  106.520593   98.691882  115.361353
#
#        ranking
# 0     7.708922
# 1     7.718217
# 2    50.248049
# 3    26.885316
# 4    50.232870
# 5    40.072525
# 6    29.447850
# 7    22.194772
# 8   131.298689
# 9    78.351597
# 10  243.606637
# 11  203.874601

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_tournois)
plt.plot(ypoints1, color = 'r', label = "Selection = tournois")

ypoints2 = np.array(GA_Cmax_random)
plt.plot(ypoints2, color = 'b', label = "Selection = random")

ypoints3 = np.array(GA_Cmax_elit)
plt.plot(ypoints3, color = 'y', label = "Selection = elit")

ypoints4 = np.array(GA_Cmax_roulette)
plt.plot(ypoints4, color = 'g', label = "Selection = roulette")

ypoints5 = np.array(GA_Cmax_ranking)
plt.plot(ypoints5, color = 'purple', label = "Selection = ranking")

ypoints6 = np.array(Best_known[:12])
plt.plot(ypoints6, color = 'black', label = "Best Known")


plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport à la strategie de selection des parents")
plt.show()

# %% [markdown]
# ## 3.2. Techniques du crossover

# %%
GA_Cmax_2points=[]
GA_Cmax_uniforme=[]

GA_temp_2points=[]
GA_temp_uniforme=[]

machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_crossover="2_points")
    GA_temp_2points.append(timeit.default_timer()-start)
    GA_Cmax_2points.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_crossover="1_point")
    GA_temp_uniforme.append(timeit.default_timer()-start)
    GA_Cmax_uniforme.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Techniques du crossover")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known":Best_known[:12],
    "Cmax 2 points" : GA_Cmax_2points,
    "Cmax uniforme" : GA_Cmax_uniforme,
    "Temps 2 points": GA_temp_2points,
    "Temps uniforme": GA_temp_uniforme

})
# Out:
# Techniques du crossover
# Cmax
#     jobs  machines  Instance  Best Known  Cmax 2 points  Cmax uniforme  \
# 0     20         5         1        1278         1297.0         1297.0
# 1     20         5         2        1359         1383.0         1383.0
# 2     20        10         1        1582         1649.0         1649.0
# 3     20        10         2        1659         1712.0         1712.0
# 4     20        20         1        2297         2395.0         2395.0
# 5     20        20         2        2099         2168.0         2168.0
# 6     50         5         1        2724         2735.0         2735.0
# 7     50         5         2        2834         2882.0         2882.0
# 8     50        10         1        2991         3167.0         3167.0
# 9     50        10         2        2867         3005.0         3005.0
# 10    50        20         1        3771         4055.0         4055.0
# 11    50        20         2        3668         3894.0         3894.0
#
#     Temps 2 points  Temps uniforme
# 0         2.998520        2.745645
# 1         2.903066        2.823769
# 2         5.674494        5.669119
# 3         5.967513        5.703182
# 4        11.487317       11.214817
# 5        11.415939       11.190245
# 6         7.299532        7.235892
# 7         7.495722        7.098111
# 8        14.369109       14.070895
# 9        14.231800       14.412738
# 10       28.590947       28.902187
# 11       29.058060       29.205732

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_2points)
plt.plot(ypoints1, color = 'r', label = "crossover = 2points")

ypoints2 = np.array(GA_Cmax_uniforme)
plt.plot(ypoints2, color = 'b', label = "crossover = uniforme")

ypoints3 = np.array(Best_known[:12])
plt.plot(ypoints3, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("ILS : Comparaison du Cmax par rapport à la methode du crossover")
plt.show()

# %% [markdown]
# ## 3.3. Techniques de mutation

# %%
GA_Cmax_inter=[]
GA_Cmax_swap=[]
GA_Cmax_LS=[]
GA_Cmax_ILS=[]
GA_Cmax_RS=[]

GA_temp_inter=[]
GA_temp_swap=[]
GA_temp_LS=[]
GA_temp_ILS=[]
GA_temp_RS=[]

Instances=[]
machines=[]
jobs=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_mutation="interchange")
    GA_temp_inter.append(timeit.default_timer()-start)
    GA_Cmax_inter.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_mutation="swap")
    GA_temp_swap.append(timeit.default_timer()-start)
    GA_Cmax_swap.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_mutation="local_search")
    GA_temp_LS.append(timeit.default_timer()-start)
    GA_Cmax_LS.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_mutation="recuit_simule")
    GA_temp_ILS.append(timeit.default_timer()-start)
    GA_Cmax_ILS.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Techniques du mutation")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "interchange" : GA_Cmax_inter,
    "swap" : GA_Cmax_swap,
    "LS":GA_Cmax_LS,
    "ILS":GA_Cmax_ILS
})
# Out:
# Techniques du mutation
# Cmax
#     jobs  machines  Instance  Best known  interchange    swap      LS     ILS
# 0     20         5         1        1278       1297.0  1297.0  1297.0  1297.0
# 1     20         5         2        1359       1383.0  1383.0  1383.0  1383.0
# 2     20        10         1        1582       1612.0  1628.0  1633.0  1649.0
# 3     20        10         2        1659       1705.0  1705.0  1712.0  1712.0
# 4     20        20         1        2297       2329.0  2365.0  2387.0  2395.0
# 5     20        20         2        2099       2129.0  2165.0  2165.0  2168.0
# 6     50         5         1        2724       2729.0  2729.0  2729.0  2735.0
# 7     50         5         2        2834       2882.0  2882.0  2882.0  2882.0
# 8     50        10         1        2991       3095.0  3132.0  3137.0  3160.0
# 9     50        10         2        2867       2980.0  2995.0  3004.0  3005.0
# 10    50        20         1        3771       3991.0  4026.0  4028.0  4053.0
# 11    50        20         2        3668       3873.0  3868.0  3868.0  3894.0

# %%
print("Techniques de mutation")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "interchange" : GA_temp_inter,
    "swap" : GA_temp_swap,
    "LS":GA_temp_LS,
    "ILS":GA_temp_ILS
})
# Out:
# Techniques de mutation
# Temps
#     jobs  machines  Instance  interchange        swap          LS         ILS
# 0     20         5         1     6.513337    6.050363   17.295218   36.831425
# 1     20         5         2     6.228790    5.875288   16.952138   34.554589
# 2     20        10         1    30.557008   15.240433   10.375046   18.532432
# 3     20        10         2    18.208187   14.337104   12.047670   21.533798
# 4     20        20         1    78.540049   23.934965   27.636248   57.518761
# 5     20        20         2    77.844322   24.473939   21.214491   34.653819
# 6     50         5         1    18.621075   22.222143   93.829089  163.029389
# 7     50         5         2    17.484623   17.683243  137.575560  164.711817
# 8     50        10         1    91.566834   62.959527  172.071592   78.946128
# 9     50        10         2   101.018731   42.655478   76.386630   73.315751
# 10    50        20         1   201.128385   94.394948  167.928428  130.704647
# 11    50        20         2   200.072909  101.895447  105.719017  158.999068

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_inter)
plt.plot(ypoints1, color = 'r', label = "Crossover = interchange")

ypoints2 = np.array(GA_Cmax_swap)
plt.plot(ypoints2, color = 'b', label = "Crossover = swap")

ypoints3 = np.array(GA_Cmax_LS)
plt.plot(ypoints3, color = 'y', label = "Crossover = LS")

ypoints4 = np.array(GA_Cmax_ILS)
plt.plot(ypoints4, color = 'g', label = "Crossover = recuit simulé")

ypoints5 = np.array(Best_known[:12])
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("ILS : Comparaison du Cmax par rapport a la strategie du crossover")
plt.show()

# %% [markdown]
# ## 3.4. Techniques de MAJ de la population

# %%
GA_Cmax_enfants=[]
GA_Cmax_enfants_population=[]
GA_Cmax_least_good=[]

GA_temp_enfants=[]
GA_temp_enfants_population=[]
GA_temp_least_good=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=40,mode_update="enfants")
    GA_temp_enfants.append(timeit.default_timer()-start)
    GA_Cmax_enfants.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=40,mode_update="enfants_population")
    GA_temp_enfants_population.append(timeit.default_timer()-start)
    GA_Cmax_enfants_population.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=40,mode_update="least_good")
    GA_temp_least_good.append(timeit.default_timer()-start)
    GA_Cmax_least_good.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Techniques du MAJ")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "enfants" : GA_Cmax_enfants,
    "population_enfants" : GA_Cmax_enfants_population,
    "moins bons":GA_Cmax_least_good
})
# Out:
# Techniques du MAJ
# Cmax
#     jobs  machines  Instance  Best known  enfants  population_enfants  \
# 0     20         5         1        1278   1297.0              1297.0
# 1     20         5         2        1359   1383.0              1367.0
# 2     20        10         1        1582   1626.0              1596.0
# 3     20        10         2        1659   1726.0              1740.0
# 4     20        20         1        2297   2347.0              2395.0
# 5     20        20         2        2099   2132.0              2183.0
# 6     50         5         1        2724   2746.0              2751.0
# 7     50         5         2        2834   2906.0              2914.0
# 8     50        10         1        2991   3221.0              3233.0
# 9     50        10         2        2867   3100.0              3135.0
# 10    50        20         1        3771   4094.0              4212.0
# 11    50        20         2        3668   4096.0              4016.0
#
#     moins bons
# 0       1297.0
# 1       1366.0
# 2       1623.0
# 3       1713.0
# 4       2361.0
# 5       2125.0
# 6       2752.0
# 7       2943.0
# 8       3195.0
# 9       3104.0
# 10      4137.0
# 11      3998.0

# %%
print("Techniques du MAJ")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "enfants" : GA_temp_enfants,
    "population_enfants" : GA_temp_enfants_population,
    "moins bons":GA_temp_least_good
})
# Out:
# Techniques du MAJ
# Temps
#     jobs  machines  Instance     enfants  population_enfants  moins bons
# 0     20         5         1    3.887119            4.653206    5.017051
# 1     20         5         2    4.111667            6.348449    6.724111
# 2     20        10         1   21.690146           19.592364   14.898755
# 3     20        10         2   12.209832           12.410366   15.589179
# 4     20        20         1   49.734144           30.867091  100.535953
# 5     20        20         2   20.002725           26.901812   45.951623
# 6     50         5         1    8.275467           22.304359   10.309137
# 7     50         5         2   19.688440           14.977724   19.572281
# 8     50        10         1   40.884900           58.841429  114.093832
# 9     50        10         2   46.276009           52.442476  116.091257
# 10    50        20         1  162.511427           95.889214  245.644250
# 11    50        20         2   81.419672          120.515646  204.819698

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_enfants)
plt.plot(ypoints1, color = 'r', label = "MAJ = enfants")

ypoints2 = np.array(GA_Cmax_enfants_population)
plt.plot(ypoints2, color = 'b', label = "MAJ = population_enfants")

ypoints3 = np.array(GA_Cmax_least_good)
plt.plot(ypoints3, color = 'y', label = "MAJ = moins bons")

ypoints4 = np.array(Best_known[:12])
plt.plot(ypoints4, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport a la strategie du crossover")
plt.show()

# %% [markdown]
# ## 3.5. Taille de la population

# %%
GA_Cmax_1=[]
GA_Cmax_2=[]
GA_Cmax_3=[]
GA_Cmax_4=[]

GA_temp_1=[]
GA_temp_2=[]
GA_temp_3=[]
GA_temp_4=[]

machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(it_number=100,nb_stag_max=100,mode_init="NEH",population_number=100,mode_arret="and")
    GA_temp_1.append(timeit.default_timer()-start)
    GA_Cmax_1.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(it_number=100,nb_stag_max=100,mode_init="NEH",population_number=150,mode_arret="and")
    GA_temp_2.append(timeit.default_timer()-start)
    GA_Cmax_2.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(it_number=100,nb_stag_max=100,mode_init="NEH",population_number=200,mode_arret="and")
    GA_temp_3.append(timeit.default_timer()-start)
    GA_Cmax_3.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Taille de la population")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "100 ind" : GA_Cmax_1,
    "150 ind" : GA_Cmax_2,
    "200 ind":GA_Cmax_3
})
# Out:
# Taille de la population
# Cmax
#     jobs  machines  Instance  Best known  500 ind  1000 ind  1500 ind
# 0     20         5         1        1278   1297.0    1297.0    1297.0
# 1     20         5         2        1359   1383.0    1383.0    1383.0
# 2     20        10         1        1582   1628.0    1628.0    1628.0
# 3     20        10         2        1659   1705.0    1705.0    1712.0
# 4     20        20         1        2297   2365.0    2380.0    2365.0
# 5     20        20         2        2099   2165.0    2165.0    2165.0
# 6     50         5         1        2724   2729.0    2729.0    2729.0
# 7     50         5         2        2834   2882.0    2882.0    2882.0
# 8     50        10         1        2991   3132.0    3132.0    3135.0
# 9     50        10         2        2867   2995.0    3005.0    3005.0
# 10    50        20         1        3771   4028.0    4026.0    4028.0
# 11    50        20         2        3668   3869.0    3884.0    3881.0

# %%
print("Taille de la population")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "100 ind" : GA_temp_1,
    "150 ind" : GA_temp_2,
    "200 ind":GA_temp_3
})
# Out:
# Taille de la population
# Temps
#     jobs  machines  Instance    500 ind   1000 ind   1500 ind
# 0     20         5         1   2.258857   3.161381   4.228387
# 1     20         5         2   2.138026   3.373345   4.408896
# 2     20        10         1   4.680695   6.283150   8.950912
# 3     20        10         2   3.986036   5.516834   7.008068
# 4     20        20         1   7.927057  12.097040  15.349628
# 5     20        20         2   7.320471  11.027324  15.154882
# 6     50         5         1   5.795406   8.686507  11.233101
# 7     50         5         2   6.140544   8.568040  12.820352
# 8     50        10         1  12.788277  17.867645  22.919546
# 9     50        10         2  11.513674  18.096877  22.798202
# 10    50        20         1  23.310529  34.611196  50.099932
# 11    50        20         2  23.304117  35.229909  45.850750

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1)
plt.plot(ypoints1, color = 'r', label = " taille population = 100")

ypoints2 = np.array(GA_Cmax_2)
plt.plot(ypoints2, color = 'b', label = "taille population = 150")

ypoints3 = np.array(GA_Cmax_3)
plt.plot(ypoints3, color = 'y', label = "taille population = 200")

ypoints5 = np.array(Best_known[:12])
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport à la taille de la population")
plt.show()

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1)
plt.plot(ypoints1, color = 'r', label = " taille population = 500")

ypoints2 = np.array(GA_Cmax_2)
plt.plot(ypoints2, color = 'b', label = "taille population = 1000")

ypoints3 = np.array(GA_Cmax_3)
plt.plot(ypoints3, color = 'y', label = "taille population = 1500")

ypoints3 = np.array(GA_Cmax_4)
plt.plot(ypoints3, color = 'g', label = "taille population = 2000")

ypoints5 = np.array(Best_known)
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport à la taille de la population")
plt.show()

# %% [markdown]
# ## 3.6. Nombre d'itération

# %%
GA_Cmax_1it=[]
GA_Cmax_2it=[]
GA_Cmax_3it=[]
GA_Cmax_4it=[]

GA_temp_1it=[]
GA_temp_2it=[]
GA_temp_3it=[]
GA_temp_4it=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,mode_init="NEH",mode_arret="and",nb_stag_max=100)
    GA_temp_1it.append(timeit.default_timer()-start)
    GA_Cmax_1it.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=150,mode_init="NEH",mode_arret="and",nb_stag_max=150)
    GA_temp_2it.append(timeit.default_timer()-start)
    GA_Cmax_2it.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=200,mode_init="NEH",mode_arret="and",nb_stag_max=200)
    GA_temp_3it.append(timeit.default_timer()-start)
    GA_Cmax_3it.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Nombre d'itération")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "100 it" : GA_Cmax_1it,
    "150 it" : GA_Cmax_2it,
    "200 it":GA_Cmax_3it
})
# Out:
# Nombre d'itération
# Cmax
#     jobs  machines  Instance  Best known  100 it  150 it  200 it
# 0     20         5         1        1278  1297.0  1297.0  1297.0
# 1     20         5         2        1359  1383.0  1383.0  1383.0
# 2     20        10         1        1582  1628.0  1628.0  1634.0
# 3     20        10         2        1659  1712.0  1705.0  1712.0
# 4     20        20         1        2297  2380.0  2380.0  2365.0
# 5     20        20         2        2099  2165.0  2165.0  2165.0
# 6     50         5         1        2724  2735.0  2729.0  2729.0
# 7     50         5         2        2834  2882.0  2882.0  2882.0
# 8     50        10         1        2991  3132.0  3135.0  3132.0
# 9     50        10         2        2867  2995.0  3005.0  3005.0
# 10    50        20         1        3771  4028.0  4026.0  4027.0
# 11    50        20         2        3668  3884.0  3884.0  3868.0

# %%
print("Nombre d'itération")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "100 it" : GA_temp_1it,
    "150 it" : GA_temp_2it,
    "200 it":GA_temp_3it
})
# Out:
# Nombre d'itération
# Temps
#     jobs  machines  Instance     100 it     150 it     200 it
# 0     20         5         1   2.188432   3.259068   4.352252
# 1     20         5         2   2.205926   3.126146   4.361330
# 2     20        10         1   4.254175   6.510468   7.637817
# 3     20        10         2   3.876328   5.697288   7.151607
# 4     20        20         1   7.904584  10.836053  13.690095
# 5     20        20         2   7.276240  10.729405  14.056769
# 6     50         5         1   5.588943   8.584784  11.230097
# 7     50         5         2   5.672573   8.120014  11.114265
# 8     50        10         1  11.456516  17.062670  24.098362
# 9     50        10         2  12.271686  17.579335  24.832140
# 10    50        20         1  22.998828  35.697036  44.900909
# 11    50        20         2  24.034173  33.479094  44.761830

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1it)
plt.plot(ypoints1, color = 'r', label = " Nombre d'itération =  100")

ypoints2 = np.array(GA_Cmax_2it)
plt.plot(ypoints2, color = 'b', label = "Nombre d'itération = 150")

ypoints3 = np.array(GA_Cmax_3it)
plt.plot(ypoints3, color = 'y', label = "Nombre d'itération = 200")

ypoints5 = np.array(Best_known[:12])
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport à la taille de la population")
plt.show()

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1it)
plt.plot(ypoints1, color = 'r', label = " Nombre d'itération =  500")

ypoints2 = np.array(GA_Cmax_2it)
plt.plot(ypoints2, color = 'b', label = "Nombre d'itération = 1000")

ypoints3 = np.array(GA_Cmax_3it)
plt.plot(ypoints3, color = 'y', label = "Nombre d'itération = 1500")

ypoints3 = np.array(GA_Cmax_4it)
plt.plot(ypoints3, color = 'g', label = "Nombre d'itération = 2000")

ypoints5 = np.array(Best_known)
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport à la taille de la population")
plt.show()

# %% [markdown]
# ## 3.7 Nombre max de stagnation

# %%
GA_Cmax_1stag=[]
GA_Cmax_2stag=[]
GA_Cmax_3stag=[]
GA_Cmax_4stag=[]

GA_temp_1stag=[]
GA_temp_2stag=[]
GA_temp_3stag=[]
GA_temp_4stag=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,mode_init="NEH",mode_arret="and",nb_stag_max=50)
    GA_temp_1stag.append(timeit.default_timer()-start)
    GA_Cmax_1stag.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,mode_init="NEH",mode_arret="and",nb_stag_max=100)
    GA_temp_2stag.append(timeit.default_timer()-start)
    GA_Cmax_2stag.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Stagnation")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "50 it" : GA_Cmax_1stag,
    "100 it" : GA_Cmax_2stag
})
# Out:
# Stagnation
# Cmax
#     jobs  machines  Instance  Best known   50 it  100 it
# 0     20         5         1        1278  1297.0  1297.0
# 1     20         5         2        1359  1383.0  1383.0
# 2     20        10         1        1582  1635.0  1628.0
# 3     20        10         2        1659  1712.0  1712.0
# 4     20        20         1        2297  2380.0  2365.0
# 5     20        20         2        2099  2165.0  2167.0
# 6     50         5         1        2724  2729.0  2729.0
# 7     50         5         2        2834  2882.0  2882.0
# 8     50        10         1        2991  3133.0  3138.0
# 9     50        10         2        2867  3005.0  3005.0
# 10    50        20         1        3771  4029.0  4027.0
# 11    50        20         2        3668  3884.0  3868.0

# %%
print("Stagnation")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "50 it" : GA_temp_1stag,
    "100 it" : GA_temp_2stag
})
# Out:
# Stagnation
# Temps
#     jobs  machines  Instance      50 it     100 it
# 0     20         5         1   1.127637   2.172289
# 1     20         5         2   1.182480   2.224033
# 2     20        10         1   2.478189   4.580063
# 3     20        10         2   1.994447   3.726782
# 4     20        20         1   5.661295   8.769103
# 5     20        20         2   4.925450   8.318217
# 6     50         5         1   5.858923   6.730220
# 7     50         5         2   3.018210   5.981818
# 8     50        10         1  11.975349  11.993068
# 9     50        10         2   6.044700  12.241017
# 10    50        20         1  23.726507  23.205556
# 11    50        20         2  16.497265  25.704286

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1stag)
plt.plot(ypoints1, color = 'r', label = " Stag = 50")

ypoints2 = np.array(GA_Cmax_2stag)
plt.plot(ypoints2, color = 'b', label = "Stag = 100")

ypoints5 = np.array(Best_known[:12])
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport au nombre max d'itération durant lesquelles on a stagnation du Cmax")
plt.show()

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1stag)
plt.plot(ypoints1, color = 'r', label = " Stag = 50")

ypoints2 = np.array(GA_Cmax_2stag)
plt.plot(ypoints2, color = 'b', label = "Stag = 100")

ypoints3 = np.array(GA_Cmax_3stag)
plt.plot(ypoints3, color = 'y', label = "Stag = 150")

ypoints5 = np.array(Best_known)
plt.plot(ypoints5, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport au nombre max d'itération durant lesquelles on a stagnation du Cmax")
plt.show()

# %% [markdown]
# ## 3.8 Taux de crossover

# %%
GA_Cmax_1cr=[]
GA_Cmax_2cr=[]
GA_Cmax_3cr=[]
GA_Cmax_4cr=[]
GA_Cmax_5cr=[]

GA_temp_1cr=[]
GA_temp_2cr=[]
GA_temp_3cr=[]
GA_temp_4cr=[]
GA_temp_5cr=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="NEH",mode_arret="and",p_crossover=0.2)
    GA_temp_1cr.append(timeit.default_timer()-start)
    GA_Cmax_1cr.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="NEH",mode_arret="and",p_crossover=0.6)
    GA_temp_3cr.append(timeit.default_timer()-start)
    GA_Cmax_3cr.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="NEH",mode_arret="and",p_crossover=1.0)
    GA_temp_5cr.append(timeit.default_timer()-start)
    GA_Cmax_5cr.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Taux crossover")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "p_crossover=0.2" : GA_Cmax_1cr,
    "p_crossover=0.6":GA_Cmax_3cr,
    "p_crossover=1.0":GA_Cmax_5cr
})
# Out:
# Taux crossover
# Cmax
#     jobs  machines  Instance  Best known  p_crossover=0.2  p_crossover=0.6  \
# 0     20         5         1        1278           1297.0           1297.0
# 1     20         5         2        1359           1383.0           1383.0
# 2     20        10         1        1582           1647.0           1628.0
# 3     20        10         2        1659           1748.0           1708.0
# 4     20        20         1        2297           2385.0           2366.0
# 5     20        20         2        2099           2192.0           2152.0
# 6     50         5         1        2724           2729.0           2729.0
# 7     50         5         2        2834           2882.0           2882.0
# 8     50        10         1        2991           3181.0           3134.0
# 9     50        10         2        2867           3049.0           2995.0
# 10    50        20         1        3771           4084.0           4026.0
# 11    50        20         2        3668           3949.0           3877.0
#
#     p_crossover=1.0
# 0            1297.0
# 1            1383.0
# 2            1635.0
# 3            1712.0
# 4            2380.0
# 5            2165.0
# 6            2729.0
# 7            2882.0
# 8            3132.0
# 9            2997.0
# 10           4030.0
# 11           3868.0

# %%
print("Taux crossover")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "p_crossover=0.2" : GA_temp_1cr,
    "p_crossover=0.6":GA_temp_3cr,
    "p_crossover=1.0":GA_temp_5cr
})
# Out:
# Taux crossover
# Temps
#     jobs  machines  Instance  p_crossover=0.2  p_crossover=0.6  \
# 0     20         5         1         2.098028         2.336892
# 1     20         5         2         2.076727         2.112851
# 2     20        10         1         4.157302         4.444307
# 3     20        10         2         4.189079         4.389932
# 4     20        20         1         8.450476         9.110556
# 5     20        20         2         8.341733         9.191898
# 6     50         5         1         5.403560         5.538973
# 7     50         5         2         5.560977         5.699996
# 8     50        10         1        10.566399        11.257630
# 9     50        10         2        10.559645        11.721513
# 10    50        20         1        21.706853        22.918134
# 11    50        20         2        22.229664        23.111487
#
#     p_crossover=1.0
# 0          2.153150
# 1          2.078093
# 2          3.815876
# 3          3.479222
# 4          7.469434
# 5          7.281905
# 6          5.673629
# 7          5.666450
# 8         11.344430
# 9         11.519047
# 10        22.949103
# 11        23.669070

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1cr)
plt.plot(ypoints1, color = 'r', label = " p_crossover=0.2")

ypoints3 = np.array(GA_Cmax_3cr)
plt.plot(ypoints3, color = 'y', label = "p_crossover=0.6")

ypoints5 = np.array(GA_Cmax_5cr)
plt.plot(ypoints5, color = 'purple', label = "p_crossover=1.0")

ypoints6 = np.array(Best_known[:12])
plt.plot(ypoints6, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport au taux du crossover")
plt.show()

# %% [markdown]
# ## 3.9 Taux de mutation

# %%
GA_Cmax_1mt=[]
GA_Cmax_2mt=[]
GA_Cmax_3mt=[]
GA_Cmax_4mt=[]
GA_Cmax_5mt=[]

GA_temp_1mt=[]
GA_temp_2mt=[]
GA_temp_3mt=[]
GA_temp_4mt=[]
GA_temp_5mt=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_arret="and",p_mutation=0.2)
    GA_temp_1mt.append(timeit.default_timer()-start)
    GA_Cmax_1mt.append(cmax)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_arret="and",p_mutation=0.6)
    GA_temp_3mt.append(timeit.default_timer()-start)
    GA_Cmax_3mt.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_arret="and",p_mutation=1.0)
    GA_temp_5mt.append(timeit.default_timer()-start)
    GA_Cmax_5mt.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Taux mutation")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "p_mutation=0.2" : GA_Cmax_1mt,
    "p_mutation=0.6":GA_Cmax_3mt,
    "p_mutation=1.0":GA_Cmax_5mt
})
# Out:
# Taux mutation
# Cmax
#     jobs  machines  Instance  Best known  p_mutation=0.2  p_mutation=0.6  \
# 0     20         5         1        1278          1297.0          1308.0
# 1     20         5         2        1359          1367.0          1372.0
# 2     20        10         1        1582          1682.0          1677.0
# 3     20        10         2        1659          1791.0          1754.0
# 4     20        20         1        2297          2413.0          2394.0
# 5     20        20         2        2099          2220.0          2198.0
# 6     50         5         1        2724          2787.0          2776.0
# 7     50         5         2        2834          2957.0          2863.0
# 8     50        10         1        2991          3351.0          3348.0
# 9     50        10         2        2867          3232.0          3227.0
# 10    50        20         1        3771          4332.0          4250.0
# 11    50        20         2        3668          4166.0          4254.0
#
#     p_mutation=1.0
# 0           1297.0
# 1           1367.0
# 2           1640.0
# 3           1750.0
# 4           2412.0
# 5           2184.0
# 6           2774.0
# 7           2942.0
# 8           3206.0
# 9           3179.0
# 10          4168.0
# 11          4168.0

# %%
print("Taux mutation")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "p_mutation=0.2" : GA_temp_1mt,
    "p_mutation=0.6":GA_temp_3mt,
    "p_mutation=1.0":GA_temp_5mt
})
# Out:
# Taux mutation
# Temps
#     jobs  machines  Instance  p_mutation=0.2  p_mutation=0.6  p_mutation=1.0
# 0     20         5         1        1.937636        2.157873        2.267697
# 1     20         5         2        1.838570        2.005548        2.340817
# 2     20        10         1        3.785840        4.148650        4.446540
# 3     20        10         2        3.487703        4.038291        4.416962
# 4     20        20         1        7.463763        7.669827        8.812158
# 5     20        20         2        8.164596        9.155427       10.314483
# 6     50         5         1        4.454679        5.039067        5.546675
# 7     50         5         2        4.481521        5.052836        5.482983
# 8     50        10         1        9.687223       10.480616       11.424105
# 9     50        10         2        9.392329       10.866239       11.209521
# 10    50        20         1       18.866462       20.570748       23.144413
# 11    50        20         2       19.265958       21.270399       22.215271

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1mt)
plt.plot(ypoints1, color = 'r', label = " p_mutation=0.2")

ypoints3 = np.array(GA_Cmax_3mt)
plt.plot(ypoints3, color = 'y', label = "p_mutation=0.6")

ypoints5 = np.array(GA_Cmax_5mt)
plt.plot(ypoints5, color = 'purple', label = "p_mutation=1.0")

ypoints6 = np.array(Best_known[:12])
plt.plot(ypoints6, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport au taux de mutation")
plt.show()

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_1mt)
plt.plot(ypoints1, color = 'r', label = " p_mutation=0.2")

ypoints3 = np.array(GA_Cmax_3mt)
plt.plot(ypoints3, color = 'y', label = "p_mutation=0.6")

ypoints5 = np.array(GA_Cmax_5mt)
plt.plot(ypoints5, color = 'purple', label = "p_mutation=1.0")

ypoints6 = np.array(Best_known)
plt.plot(ypoints6, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport au taux de mutation")
plt.show()

# %% [markdown]
# ## 3.10. Initialisation:

# %%
GA_Cmax_palmer=[]
GA_Cmax_neh=[]
GA_Cmax_cds=[]
GA_Cmax_random=[]

GA_temp_palmer=[]
GA_temp_neh=[]
GA_temp_cds=[]
GA_temp_random=[]

machines=[]
jobs=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="random")
    GA_temp_random.append(timeit.default_timer()-start)
    GA_Cmax_random.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="palmer")
    GA_temp_palmer.append(timeit.default_timer()-start)
    GA_Cmax_palmer.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="NEH")
    GA_temp_neh.append(timeit.default_timer()-start)
    GA_Cmax_neh.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="CDS")
    GA_temp_cds.append(timeit.default_timer()-start)
    GA_Cmax_cds.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
print("Initialisation")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "Random" : GA_Cmax_random,
    "Palmer" : GA_Cmax_palmer,
    "NEH":GA_Cmax_neh,
    "CDS":GA_Cmax_cds

})
# Out:
# Initialisation
# Cmax
#     jobs  machines  Instance  Best known  Random  Palmer     NEH     CDS
# 0     20         5         1        1278  1324.0  1305.0  1297.0  1359.0
# 1     20         5         2        1359  1373.0  1383.0  1383.0  1372.0
# 2     20        10         1        1582  1629.0  1633.0  1628.0  1664.0
# 3     20        10         2        1659  1803.0  1705.0  1705.0  1812.0
# 4     20        20         1        2297  2419.0  2558.0  2365.0  2458.0
# 5     20        20         2        2099  2182.0  2189.0  2168.0  2214.0
# 6     50         5         1        2724  2823.0  2736.0  2729.0  2738.0
# 7     50         5         2        2834  2915.0  2890.0  2882.0  2972.0
# 8     50        10         1        2991  3289.0  3302.0  3132.0  3219.0
# 9     50        10         2        2867  3189.0  2999.0  2998.0  3182.0
# 10    50        20         1        3771  4337.0  4110.0  4026.0  4114.0
# 11    50        20         2        3668  4162.0  4063.0  3868.0  3999.0

# %%
print("Initialisation")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "Random" : GA_temp_random,
    "Palmer" : GA_temp_palmer,
    "NEH":GA_temp_neh,
    "CDS":GA_temp_cds

})
# Out:
# Initialisation
# Temps
#     jobs  machines  Instance  Best known     Random     Palmer        NEH  \
# 0     20         5         1        1278   2.841373   2.603239   2.548434
# 1     20         5         2        1359   2.666378   2.634246   2.479788
# 2     20        10         1        1582   5.346024   4.892401   5.037820
# 3     20        10         2        1659   5.619656   5.233893   4.422387
# 4     20        20         1        2297  10.103711  11.364442   9.112995
# 5     20        20         2        2099  10.172829  10.194346   8.526553
# 6     50         5         1        2724   6.947910   6.862811   6.727357
# 7     50         5         2        2834   6.646146   6.477510   6.941993
# 8     50        10         1        2991  13.633878  13.275028  14.035942
# 9     50        10         2        2867  13.844725  13.302493  13.319807
# 10    50        20         1        3771  27.514871  27.292202  28.964173
# 11    50        20         2        3668  27.108374  26.410293  27.590501
#
#           CDS
# 0    2.669762
# 1    2.639865
# 2    5.024405
# 3    5.382441
# 4   10.697311
# 5   10.678648
# 6    6.645854
# 7    6.369275
# 8   13.588175
# 9   13.626836
# 10  27.209083
# 11  27.135059

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_random)
plt.plot(ypoints1, color = 'r', label = " init = Random")

ypoints2 = np.array(GA_Cmax_palmer)
plt.plot(ypoints2, color = 'b', label = " init = Palmer")

ypoints3 = np.array(GA_Cmax_neh)
plt.plot(ypoints3, color = 'y', label = " init = NEH amélioré")

ypoints4 = np.array(GA_Cmax_cds)
plt.plot(ypoints4, color = 'g', label = " init = CDS")

ypoints6 = np.array(Best_known[:12])
plt.plot(ypoints6, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport aux méthodes d'initialisation de la population.")
plt.show()

# %% [markdown]
# ## 3.11. Comparaison entre les différentes Hybridations: (Initialisation,mutation,sortie)

# %%
GA_Cmax_hyb=[]
GA_Cmax_recuit=[]
GA_Cmax_LS=[]
GA_Cmax_neh=[]
GA_Cmax_v=[]

GA_temp_hyb=[]
GA_temp_recuit=[]
GA_temp_LS=[]
GA_temp_neh=[]
GA_temp_v=[]

jobs=[]
machines=[]
Instances=[]

# %%
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_sorti="recuit_simule")
    GA_temp_recuit.append(timeit.default_timer()-start)
    GA_Cmax_recuit.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="random")
    GA_temp_v.append(timeit.default_timer()-start)
    GA_Cmax_v.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_init="NEH")
    GA_temp_neh.append(timeit.default_timer()-start)
    GA_Cmax_neh.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=300,it_number=300,nb_stag_max=100,mode_init="NEH",mode_crossover="local_search")
    GA_temp_LS.append(timeit.default_timer()-start)
    GA_Cmax_LS.append(cmax)
    
    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_sorti="recuit_simule",mode_init="NEH",mode_crossover="local_search")
    GA_temp_hyb.append(timeit.default_timer()-start)
    GA_Cmax_hyb.append(cmax)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_10machines_1.txt
# 050jobs_10machines_2.txt
# 050jobs_20machines_1.txt
# 050jobs_20machines_2.txt

# %%
GA_temp_hyb2=[]
GA_Cmax_hyb2=[]
#On parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard2")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard2/"+filename)
    #Instances.append((i%2)+1)
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    #machines.append(flowshop.M)
    #jobs.append(flowshop.N)

    start = timeit.default_timer()
    sigma, cmax = flowshop.genetic_algorithm(population_number=100,it_number=100,nb_stag_max=100,mode_sorti="local_search",mode_init="NEH",mode_mutation="local_search")
    GA_temp_hyb2.append(timeit.default_timer()-start)
    GA_Cmax_hyb2.append(cmax)
    print(cmax)
# Out:
# 020jobs_05machines_1.txt
# 1297.0
# 020jobs_05machines_2.txt
# 1383.0
# 020jobs_10machines_1.txt
# 1633.0
# 020jobs_10machines_2.txt
# 1712.0
# 020jobs_20machines_1.txt
# 2387.0
# 020jobs_20machines_2.txt
# 2165.0
# 050jobs_05machines_1.txt
# 2729.0
# 050jobs_05machines_2.txt
# 2882.0
# 050jobs_10machines_1.txt
# 3139.0
# 050jobs_10machines_2.txt
# 3005.0
# 050jobs_20machines_1.txt
# 4028.0
# 050jobs_20machines_2.txt
# 3868.0

# %%
print("Hybridation")
print("Cmax")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best known":Best_known[:12],
    "init = Random | mut = swap | sortie = rien" : GA_Cmax_v,
    "init = Random | mut = swap | sortie = RS" : GA_Cmax_recuit,
    "init = NEH | mut = swap | sortie = rien":GA_Cmax_neh,
    "init = Random | mut = LS | sortie = rien":GA_Cmax_LS,
    "init = NEH | mut = LS | sortie = RS":GA_Cmax_hyb

})
# Out:
# Hybridation
# Cmax
#     jobs  machines  Instance  Best known  \
# 0     20         5         1        1278
# 1     20         5         2        1359
# 2     20        10         1        1582
# 3     20        10         2        1659
# 4     20        20         1        2297
# 5     20        20         2        2099
# 6     50         5         1        2724
# 7     50         5         2        2834
# 8     50        10         1        2991
# 9     50        10         2        2867
# 10    50        20         1        3771
# 11    50        20         2        3668
#
#     init = Random | mut = swap | sortie = rien  \
# 0                                       1318.0
# 1                                       1368.0
# 2                                       1633.0
# 3                                       1778.0
# 4                                       2349.0
# 5                                       2226.0
# 6                                       2755.0
# 7                                       2980.0
# 8                                       3259.0
# 9                                       3139.0
# 10                                      4307.0
# 11                                      4232.0
#
#     init = Random | mut = swap | sortie = RS  \
# 0                                     1374.0
# 1                                     1439.0
# 2                                     1813.0
# 3                                     1892.0
# 4                                     2521.0
# 5                                     2408.0
# 6                                     2840.0
# 7                                     3052.0
# 8                                     3473.0
# 9                                     3364.0
# 10                                    4564.0
# 11                                    4407.0
#
#     init = NEH | mut = swap | sortie = rien  \
# 0                                    1297.0
# 1                                    1383.0
# 2                                    1635.0
# 3                                    1705.0
# 4                                    2365.0
# 5                                    2165.0
# 6                                    2729.0
# 7                                    2882.0
# 8                                    3139.0
# 9                                    2995.0
# 10                                   4027.0
# 11                                   3884.0
#
#     init = Random | mut = LS | sortie = rien  \
# 0                                     1297.0
# 1                                     1383.0
# 2                                     1633.0
# 3                                     1712.0
# 4                                     2387.0
# 5                                     2165.0
# 6                                     2729.0
# 7                                     2882.0
# 8                                     3139.0
# 9                                     3004.0
# 10                                    4023.0
# 11                                    3868.0
#
#     init = NEH | mut = LS | sortie = RS
# 0                                1369.0
# 1                                1422.0
# 2                                1832.0
# 3                                1857.0
# 4                                2524.0
# 5                                2318.0
# 6                                2826.0
# 7                                2992.0
# 8                                3543.0
# 9                                3330.0
# 10                               4526.0
# 11                               4343.0

# %%
GA_Cmax_hyb=[1369.0,1422.0,1832.0,1857.0,2524.0,2318.0,2826.0,2992.0,3543.0,3330.0,4526.0,4343.0]
GA_Cmax_LS=[1297.0,1383.0,1633.0,1712.0,2387.0,2165.0,2729.0,2882.0,3139.0,3004.0,4023.0,3868.0]
GA_Cmax_v=[1318.0,1368.0,1633.0,1778.0,2349.0,2226.0,2755.0,2980.0,3259.0,3139.0,4307.0,4232.0]
GA_Cmax_recuit=[1374.0,1439.0,1813.0,1892.0,2521.0,2408.0,2840.0,3052.0,3473.0,3364.0,4564.0,4407.0]
GA_Cmax_neh=[1297.0,1383.0,1635.0,1705.0,2365.0,2165.0,2729.0,2882.0,3139.0,2995.0,4027.0,3884.0]

# %%
print("Hybridation")
print("Temps")
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "init = Random | mut = swap | sortie = rien" : GA_temp_v,
    "init = Random | mut = swap | sortie = RS" : GA_temp_recuit,
    "init = NEH | mut = swap | sortie = rien":GA_temp_neh,
    "init = Random | mut = LS | sortie = rien":GA_temp_LS,
    "init = NEH | mut = LS | sortie = RS":GA_temp_hyb

})
# Out:
# Hybridation
# Temps
#     jobs  machines  Instance  init = Random | mut = swap | sortie = rien  \
# 0     20         5         1                                    9.991524
# 1     20         5         2                                   10.079073
# 2     20        10         1                                   19.849157
# 3     20        10         2                                   20.589397
# 4     20        20         1                                   40.367274
# 5     20        20         2                                   37.427764
# 6     50         5         1                                   26.404777
# 7     50         5         2                                   24.811935
# 8     50        10         1                                   52.706112
# 9     50        10         2                                   49.451864
# 10    50        20         1                                  100.718220
# 11    50        20         2                                   97.207500
#
#     init = Random | mut = swap | sortie = RS  \
# 0                                  12.047774
# 1                                  12.213546
# 2                                  23.751978
# 3                                  23.717366
# 4                                  44.766326
# 5                                  47.273805
# 6                                  30.959230
# 7                                  30.327359
# 8                                  61.816011
# 9                                  59.163294
# 10                                128.114171
# 11                                116.557619
#
#     init = NEH | mut = swap | sortie = rien  \
# 0                                  9.419466
# 1                                  9.938857
# 2                                 16.653629
# 3                                 16.214863
# 4                                 33.432670
# 5                                 34.092353
# 6                                 25.733853
# 7                                 25.799768
# 8                                 55.222157
# 9                                 50.961892
# 10                               102.346821
# 11                                99.705940
#
#     init = Random | mut = LS | sortie = rien  \
# 0                                  80.117011
# 1                                  82.938325
# 2                                  49.255850
# 3                                  74.996797
# 4                                 100.340866
# 5                                  96.440074
# 6                                 368.869209
# 7                                 603.980844
# 8                                 894.561079
# 9                                 233.227106
# 10                               1345.199509
# 11                                489.426928
#
#     init = NEH | mut = LS | sortie = RS
# 0                             36.384169
# 1                             34.687392
# 2                             17.257528
# 3                             26.811302
# 4                             33.146676
# 5                             48.220861
# 6                            193.845383
# 7                            214.912354
# 8                            252.529140
# 9                            112.647526
# 10                           247.235599
# 11                           164.552548

# %%
plt.figure(figsize=(14,8))

ypoints1 = np.array(GA_Cmax_v)
plt.plot(ypoints1, color = 'r', label = " init = Random | mut = swap | sortie = rien")

ypoints2 = np.array(GA_Cmax_recuit)
plt.plot(ypoints2, color = 'b', label = " init = Random | mut = swap | sortie = RS")

ypoints3 = np.array(GA_Cmax_neh)
plt.plot(ypoints3, color = 'y', label = " init = NEH | mut = swap | sortie = rien")

ypoints4 = np.array(GA_Cmax_LS)
plt.plot(ypoints4, color = 'g', label = "init = NEH | mut = LS | sortie = rien")

ypoints5 = np.array(GA_Cmax_hyb)
plt.plot(ypoints5, color = 'purple', label = "init = NEH | mut = LS | sortie = RS")

ypoints5 = np.array(GA_Cmax_hyb2)
plt.plot(ypoints5, color = 'pink', label = "init = NEH | mut = LS | sortie = LS")

ypoints6 = np.array(Best_known[:12])
plt.plot(ypoints6, color = 'black', label = "Best known")

plt.legend();
plt.ylabel("Cmax");
plt.title("AG : Comparaison du Cmax par rapport aux méthodes d'hybridation.")
plt.show()

# %% [markdown]
# # 4.Sélection d'attributs (Pearson)

# %% [markdown]
# ## 4.1 NEH_ameliore

# %%
dic = { "order": [True, False],
        "pas" : [x for x in range(1,10)],
        "tie" : ["First", "Last", "Random", "KK2", "SMM"]}

# %%
X_train = []
Y_train = []
data_frame = pd.DataFrame({})

# %%
files=os.listdir("./Instances_Taillard4")
RS = RandomSearch.RandomSearch()
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard4/"+filename)
    print(filename)
    flowshop = fsp.FlowShop(data)

    datai = RS.generer_dataset(flowshop.NEH_ameliore, dic, 100)
    data_frame = data_frame.append(datai, ignore_index=True)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_10.txt
# 020jobs_05machines_2.txt
# 020jobs_05machines_3.txt
# 020jobs_05machines_4.txt
# 020jobs_05machines_5.txt
# 020jobs_05machines_6.txt
# 020jobs_05machines_7.txt
# 020jobs_05machines_8.txt
# 020jobs_05machines_9.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_10.txt
# 020jobs_10machines_2.txt
# 020jobs_10machines_3.txt
# 020jobs_10machines_4.txt
# 020jobs_10machines_5.txt
# 020jobs_10machines_6.txt
# 020jobs_10machines_7.txt
# 020jobs_10machines_8.txt
# 020jobs_10machines_9.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_10.txt
# 020jobs_20machines_2.txt
# 020jobs_20machines_3.txt
# 020jobs_20machines_4.txt
# 020jobs_20machines_5.txt
# 020jobs_20machines_6.txt
# 020jobs_20machines_7.txt
# 020jobs_20machines_8.txt
# 020jobs_20machines_9.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_10.txt
# 050jobs_05machines_2.txt
# 050jobs_05machines_3.txt
# 050jobs_05machines_4.txt
# 050jobs_05machines_5.txt
# 050jobs_05machines_6.txt
# 050jobs_05machines_7.txt
# 050jobs_05machines_8.txt
# 050jobs_05machines_9.txt

# %%
X_train, Y_train = RS.generer_Xtrain_Ytrain(data_frame)

# %%
len(data_frame)
# Out:
# 4000

# %%
from sklearn.feature_selection import f_regression
f, p = f_regression(X_train, Y_train)

# %%
f,p
# Out:
# (array([ 6.34718441, 19.65572242,  0.71171148]),
#  array([1.17954517e-02, 9.52141223e-06, 3.98926700e-01]))

# %%
labels = [ "order", "pas", "tie"]
x_pos = range(len(f))
plt.figure(figsize=(15,5))
plt.bar(labels, f, color="blue")
plt.xlabel("Les attributs", FontSize = 12)
plt.ylabel("Valeur F de Pearson", FontSize = 12)
plt.title("Comparison entre les attributs en terme de Pearson", fontweight='bold', FontSize = 14)

plt.xticks(x_pos, labels, fontweight='bold', FontSize = 11)

plt.show()

# %%
# Selection des attributs  (80% des attributs à sélectionnée)
from sklearn.feature_selection import SelectPercentile
selecteur = SelectPercentile(score_func=f_regression, percentile= 80)

X_train_new = selecteur.fit_transform(X_train, Y_train)

labels_new = selecteur.transform(np.array(labels).reshape(1, len(labels))).flatten()

# %%
labels_new
# Out:
# array(['order', 'pas'], dtype='<U5')

# %% [markdown]
# # 5.Parameter tunning

# %% [markdown]
# ## 4.1 NEH_ameliore

# %%
neh_cmax_tunning = []
param_list_tunning = []
machines=[]
jobs=[]
Instances=[]

dic_tunning = { "order": [True, False],
        "pas" : [x for x in range(1,10)],
        "tie" : ["First", "Last", "Random", "KK2", "SMM"]}

# %%
#on parcours les fichiers contenant les instances
files=os.listdir("./Instances_Taillard4")
i=0
for filename in files:
    
    data=np.loadtxt("./Instances_Taillard4/"+filename)
    Instances.append((i%10 + 1))
    i+=1
    print(filename)
    flowshop = fsp.FlowShop(data)
    machines.append(flowshop.M)
    jobs.append(flowshop.N)
    
    #NEH Ameliorée
    RS = RandomSearch.RandomSearch()
    param, cmax, sequence = RS.run(flowshop.NEH_ameliore, dic_tunning, 500, 1)
    neh_cmax_tunning.append(int(cmax))
    param_list_tunning.append(param)
# Out:
# 020jobs_05machines_1.txt
# 020jobs_05machines_2.txt
# 020jobs_05machines_3.txt
# 020jobs_05machines_4.txt
# 020jobs_05machines_5.txt
# 020jobs_05machines_6.txt
# 020jobs_05machines_7.txt
# 020jobs_05machines_8.txt
# 020jobs_05machines_9.txt
# 020jobs_05machines__10.txt
# 020jobs_10machines_1.txt
# 020jobs_10machines_2.txt
# 020jobs_10machines_3.txt
# 020jobs_10machines_4.txt
# 020jobs_10machines_5.txt
# 020jobs_10machines_6.txt
# 020jobs_10machines_7.txt
# 020jobs_10machines_8.txt
# 020jobs_10machines_9.txt
# 020jobs_10machines__10.txt
# 020jobs_20machines_1.txt
# 020jobs_20machines_2.txt
# 020jobs_20machines_3.txt
# 020jobs_20machines_4.txt
# 020jobs_20machines_5.txt
# 020jobs_20machines_6.txt
# 020jobs_20machines_7.txt
# 020jobs_20machines_8.txt
# 020jobs_20machines_9.txt
# 020jobs_20machines__10.txt
# 050jobs_05machines_1.txt
# 050jobs_05machines_2.txt
# 050jobs_05machines_3.txt
# 050jobs_05machines_4.txt
# 050jobs_05machines_5.txt
# 050jobs_05machines_6.txt
# 050jobs_05machines_7.txt
# 050jobs_05machines_8.txt
# 050jobs_05machines_9.txt
# 050jobs_05machines__10.txt

# %%
pd.DataFrame({
    "jobs":jobs,
    "machines":machines,
    "Instance" : Instances,
    "Best Known" : [1278, 1359, 1081, 1293, 1235, 1195, "Not mentioned", 1206, 1230,1108,
                    1582, 1659, 1496, 1377, 1419, 1397, 1484, 1538, 1593, 1591,
                    2297, 2099, 2326, 2223, 2291, 2226, 2273, 2200, 2237, 2178,
                    2724, 2834, 2621, 2751, 2863, 2829, 2725, 2683, 2552,2782],
    "Cmax" : neh_cmax_tunning,
    "order" : [elem["order"]  for elem in param_list_tunning],
    "pas" :  [elem["pas"]  for elem in param_list_tunning],
    "tie" : [elem["tie"]  for elem in param_list_tunning]
})
# Out:
#     jobs  machines  Instance     Best Known  Cmax  order  pas     tie
# 0     20         5         1           1278  1297   True    4     SMM
# 1     20         5         2           1359  1367  False    4     SMM
# 2     20         5         3           1081  1111   True    1     SMM
# 3     20         5         4           1293  1304   True    1  Random
# 4     20         5         5           1235  1269  False    1  Random
# 5     20         5         6           1195  1215   True    1  Random
# 6     20         5         7  Not mentioned  1251   True    1     KK2
# 7     20         5         8           1206  1214   True    1    Last
# 8     20         5         9           1230  1265   True    1     SMM
# 9     20         5        10           1108  1128  False    1   First
# 10    20        10         1           1582  1643  False    1     SMM
# 11    20        10         2           1659  1716   True    1     SMM
# 12    20        10         3           1496  1540   True    1  Random
# 13    20        10         4           1377  1409   True    1  Random
# 14    20        10         5           1419  1473   True    1     KK2
# 15    20        10         6           1397  1431   True    1   First
# 16    20        10         7           1484  1531   True    1   First
# 17    20        10         8           1538  1591   True    1  Random
# 18    20        10         9           1593  1636  False    1  Random
# 19    20        10        10           1591  1658   True    1   First
# 20    20        20         1           2297  2400   True    1     KK2
# 21    20        20         2           2099  2135   True    1    Last
# 22    20        20         3           2326  2387   True    1    Last
# 23    20        20         4           2223  2248   True    1  Random
# 24    20        20         5           2291  2363   True    1  Random
# 25    20        20         6           2226  2309   True    1   First
# 26    20        20         7           2273  2331   True    1   First
# 27    20        20         8           2200  2250   True    1  Random
# 28    20        20         9           2237  2283   True    1     KK2
# 29    20        20        10           2178  2234   True    1  Random
# 30    50         5         1           2724  2724   True    1     KK2
# 31    50         5         2           2834  2882   True    1     KK2
# 32    50         5         3           2621  2654   True    1     SMM
# 33    50         5         4           2751  2762   True    1  Random
# 34    50         5         5           2863  2872  False    1    Last
# 35    50         5         6           2829  2831   True    1  Random
# 36    50         5         7           2725  2736   True    1     SMM
# 37    50         5         8           2683  2704   True    1   First
# 38    50         5         9           2552  2564   True    1   First
# 39    50         5        10           2782  2784  False    1  Random
